# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
import os
os.chdir('./drive/My Drive/TESI/ST-ResNet')
# Out:
# Mounted at /content/drive/

# %%
from __future__ import print_function
import os
import pickle
import numpy as np
import time
import h5py
import math

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from deepst.models.STResNet import stresnet
import deepst.metrics as metrics
from deepst.datasets import BikeNYC

# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.4.3
# 2.3.0

# %%
np.random.seed(1337)  # for reproducibility

# parameters
DATAPATH = '../data'  # data path, you may set your own data path with the global envirmental variable DATAPATH
CACHEDATA = True  # cache data or NOT
path_cache = os.path.join(DATAPATH, 'CACHE', 'ST-ResNet')  # cache path
nb_epoch = 100  # number of epoch at training stage
# nb_epoch_cont = 100  # number of epoch at training (cont) stage
batch_size = 32  # batch size

T = 24  # number of time intervals in one day
lr = 0.0002  # learning rate
len_closeness = 3  # length of closeness dependent sequence
len_period = 1  # length of peroid dependent sequence
len_trend = 1  # length of trend dependent sequence
nb_residual_unit = 4 # paper says 4 for BikeNYC

nb_flow = 2  # there are two types of flows: inflow and outflow
# divide data into two subsets: Train & Test, of which the test set is the
# last 10 days
days_test = 10
len_test = T * days_test
map_height, map_width = 16, 8  # grid size
# For NYC Bike data, there are 81 available grid-based areas, each of
# which includes at least ONE bike station. Therefore, we modify the final
# RMSE by multiplying the following factor (i.e., factor).
nb_area = 81
m_factor = math.sqrt(1. * map_height * map_width / nb_area)
print('factor: ', m_factor)
path_result = 'RET'
path_model = 'MODEL'
# Out:
# factor:  1.2570787221094177

# %%
if os.path.isdir(path_result) is False:
    os.mkdir(path_result)
if os.path.isdir(path_model) is False:
    os.mkdir(path_model)
if CACHEDATA and os.path.isdir(path_cache) is False:
    os.mkdir(path_cache)

# %%
def build_model(external_dim):
    c_conf = (len_closeness, nb_flow, map_height,
              map_width) if len_closeness > 0 else None
    p_conf = (len_period, nb_flow, map_height,
              map_width) if len_period > 0 else None
    t_conf = (len_trend, nb_flow, map_height,
              map_width) if len_trend > 0 else None
    model = stresnet(c_conf=c_conf, p_conf=p_conf, t_conf=t_conf,
                     external_dim=external_dim, nb_residual_unit=nb_residual_unit)
    adam = Adam(lr=lr)
    model.compile(loss='mse', optimizer=adam, metrics=[metrics.rmse])
    model.summary()
    # from keras.utils.visualize_util import plot
    # plot(model, to_file='model.png', show_shapes=True)
    return model

# %%
def read_cache(fname):
    mmn = pickle.load(open('preprocessing.pkl', 'rb'))

    f = h5py.File(fname, 'r')
    num = int(f['num'].value)
    X_train, Y_train, X_test, Y_test = [], [], [], []
    for i in range(num):
        X_train.append(f['X_train_%i' % i].value)
        X_test.append(f['X_test_%i' % i].value)
    Y_train = f['Y_train'].value
    Y_test = f['Y_test'].value
    external_dim = f['external_dim'].value
    timestamp_train = f['T_train'].value
    timestamp_test = f['T_test'].value
    f.close()

    return X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test

# %%
def cache(fname, X_train, Y_train, X_test, Y_test, external_dim, timestamp_train, timestamp_test):
    h5 = h5py.File(fname, 'w')
    h5.create_dataset('num', data=len(X_train))

    for i, data in enumerate(X_train):
        h5.create_dataset('X_train_%i' % i, data=data)
    # for i, data in enumerate(Y_train):
    for i, data in enumerate(X_test):
        h5.create_dataset('X_test_%i' % i, data=data)
    h5.create_dataset('Y_train', data=Y_train)
    h5.create_dataset('Y_test', data=Y_test)
    external_dim = -1 if external_dim is None else int(external_dim)
    h5.create_dataset('external_dim', data=external_dim)
    h5.create_dataset('T_train', data=timestamp_train)
    h5.create_dataset('T_test', data=timestamp_test)
    h5.close()

# %%
print("loading data...")
ts = time.time()
fname = os.path.join(path_cache, 'BikeNYC_C{}_P{}_T{}.h5'.format(
    len_closeness, len_period, len_trend))
if os.path.exists(fname) and CACHEDATA:
    X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test = read_cache(
        fname)
    print("load %s successfully" % fname)
else:
    X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test = BikeNYC.load_data(
        T=T, nb_flow=nb_flow, len_closeness=len_closeness, len_period=len_period, len_trend=len_trend, len_test=len_test,
        preprocess_name='preprocessing.pkl', meta_data=True, datapath=DATAPATH)
    if CACHEDATA:
        cache(fname, X_train, Y_train, X_test, Y_test,
              external_dim, timestamp_train, timestamp_test)

print("\n days (test): ", [v[:8] for v in timestamp_test[0::T]])
print("\nelapsed time (loading data): %.3f seconds\n" % (time.time() - ts))

print('=' * 10)
# Out:
# loading data...
# /content/drive/My Drive/TESI/ST-ResNet/deepst/datasets/__init__.py:7: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   data = f['data'].value
# /content/drive/My Drive/TESI/ST-ResNet/deepst/datasets/__init__.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   timestamps = f['date'].value
# incomplete days:  []
# train_data shape:  (4152, 2, 16, 8)
# min: 0.0 max: 267.0
# XC shape:  (4224, 6, 16, 8) XP shape:  (4224, 2, 16, 8) XT shape:  (4224, 2, 16, 8) Y shape: (4224, 2, 16, 8)
# XC shape:  (4224, 6, 16, 8) XP shape:  (4224, 2, 16, 8) XT shape:  (4224, 2, 16, 8) Y shape: (4224, 2, 16, 8)
# train shape: (3984, 6, 16, 8) (3984, 2, 16, 8) test shape:  (240, 6, 16, 8) (240, 2, 16, 8)
# (3984, 6, 16, 8)
# (3984, 2, 16, 8)
# (3984, 2, 16, 8)
# (3984, 8)
#
# (240, 6, 16, 8)
# (240, 2, 16, 8)
# (240, 2, 16, 8)
# (240, 8)
#
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
#
# elapsed time (loading data): 8.950 seconds
#
# ==========

# %%
#from deepst.datasets import stat; stat('BJ16_M32x32_T30_InOut.h5')
f = h5py.File('../data/BikeNYC/NYC14_M16x8_T60_NewEnd.h5', 'r')
print(len(f['date']))
# print(f['data'][1][0][0])

print(len(X_train))
print(len(X_train[0]))
print(len(X_train[0][0]))
xtrain_np = np.array(X_train[0], dtype=np.float32)
print(xtrain_np.shape)
print(len(Y_train))
ytrain_np = np.array(Y_train, dtype=np.float32)
print(ytrain_np.shape)
print(len(timestamp_train))
print(len(timestamp_test))
print(len(X_test))
# Out:
# 4392
# 4
# 3480
# 6
# (3480, 6, 16, 8)
# 3480
# (3480, 2, 16, 8)
# 3480
# 240
# 4

# %%
print("compiling model...")
ts = time.time()
model = build_model(external_dim)
hyperparams_name = 'BikeNYC.c{}.p{}.t{}.resunit{}.lr{}'.format(
    len_closeness, len_period, len_trend, nb_residual_unit, lr)
fname_param = os.path.join('MODEL', '{}.best.h5'.format(hyperparams_name))

early_stopping = EarlyStopping(monitor='val_rmse', patience=2, mode='min')
model_checkpoint = ModelCheckpoint(
    fname_param, monitor='val_rmse', verbose=0, save_best_only=True, mode='min')

print("\nelapsed time (compiling model): %.3f seconds\n" %
      (time.time() - ts))

print('=' * 10)
# Out:
# compiling model...
# **at the first time, it takes a few minites to compile if you use [Theano] as the backend**
# (None, 2, 16, 8)
# (None, 2, 16, 8)
# (None, 2, 16, 8)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6, 16, 8)]   0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2, 16, 8)]   0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 2, 16, 8)]   0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 16, 8)    3520        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 16, 8)    1216        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 16, 8)    1216        input_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 16, 8)    0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 16, 8)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 16, 8)    0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 16, 8)    36928       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 16, 8)    36928       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 16, 8)    36928       activation_18[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 16, 8)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 16, 8)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 16, 8)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 16, 8)    36928       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 16, 8)    36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 16, 8)    36928       activation_19[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 16, 8)    0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 16, 8)    0           conv2d_10[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 16, 8)    0           conv2d_20[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 16, 8)    0           add[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 16, 8)    0           add_4[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 16, 8)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 16, 8)    36928       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 16, 8)    36928       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 16, 8)    36928       activation_20[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 16, 8)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 16, 8)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 16, 8)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 16, 8)    36928       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 16, 8)    36928       activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 16, 8)    36928       activation_21[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 16, 8)    0           add[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 16, 8)    0           add_4[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 16, 8)    0           add_8[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 16, 8)    0           add_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 16, 8)    0           add_5[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 16, 8)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 16, 8)    36928       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 16, 8)    36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 16, 8)    36928       activation_22[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 16, 8)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 16, 8)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 16, 8)    0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 16, 8)    36928       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 16, 8)    36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 16, 8)    36928       activation_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 16, 8)    0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 16, 8)    0           add_5[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 16, 8)    0           add_9[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 16, 8)    0           add_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 16, 8)    0           add_6[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 16, 8)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 16, 8)    36928       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 16, 8)    36928       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 16, 8)    36928       activation_24[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 16, 8)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 16, 8)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 16, 8)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 16, 8)    36928       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 16, 8)    36928       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 16, 8)    36928       activation_25[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 16, 8)    0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 16, 8)    0           add_6[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 16, 8)    0           add_10[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           90          input_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 16, 8)    0           add_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 16, 8)    0           add_7[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 16, 8)    0           add_11[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 10)           0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 2, 16, 8)     1154        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 16, 8)     1154        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 2, 16, 8)     1154        activation_26[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          2816        activation_27[0][0]
# __________________________________________________________________________________________________
# i_layer (iLayer)                (None, 2, 16, 8)     256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# i_layer_1 (iLayer)              (None, 2, 16, 8)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# i_layer_2 (iLayer)              (None, 2, 16, 8)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 2, 16, 8)     0           i_layer[0][0]
#                                                                  i_layer_1[0][0]
#                                                                  i_layer_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 2, 16, 8)     0           activation_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 2, 16, 8)     0           add_12[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 2, 16, 8)     0           add_13[0][0]
# ==================================================================================================
# Total params: 899,360
# Trainable params: 899,360
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# elapsed time (compiling model): 6.679 seconds
#
# ==========

# %%
print("training model...")
ts = time.time()
history = model.fit(X_train, Y_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    validation_split=0.1,
                    callbacks=[model_checkpoint],
                    # callbacks=[early_stopping, model_checkpoint],
                    verbose=1)
model.save_weights(os.path.join(
    'MODEL', '{}.h5'.format(hyperparams_name)), overwrite=True)
pickle.dump((history.history), open(os.path.join(
    path_result, '{}.history.pkl'.format(hyperparams_name)), 'wb'))
print("\nelapsed time (training): %.3f seconds\n" % (time.time() - ts))
# Out:
# training model...
# Epoch 1/100
# 113/113 [==============================] - 2s 15ms/step - loss: 0.0308 - rmse: 0.1653 - val_loss: 0.0296 - val_rmse: 0.1716
# Epoch 2/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0170 - rmse: 0.1275 - val_loss: 0.0121 - val_rmse: 0.1105
# Epoch 3/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0073 - rmse: 0.0842 - val_loss: 0.0058 - val_rmse: 0.0763
# Epoch 4/100
# 113/113 [==============================] - 1s 11ms/step - loss: 0.0044 - rmse: 0.0656 - val_loss: 0.0042 - val_rmse: 0.0652
# Epoch 5/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0036 - rmse: 0.0593 - val_loss: 0.0056 - val_rmse: 0.0753
# Epoch 6/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0033 - rmse: 0.0565 - val_loss: 0.0033 - val_rmse: 0.0571
# Epoch 7/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0030 - rmse: 0.0546 - val_loss: 0.0031 - val_rmse: 0.0556
# Epoch 8/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0027 - rmse: 0.0517 - val_loss: 0.0030 - val_rmse: 0.0550
# Epoch 9/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0026 - rmse: 0.0509 - val_loss: 0.0040 - val_rmse: 0.0633
# Epoch 10/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0029 - rmse: 0.0536 - val_loss: 0.0031 - val_rmse: 0.0553
# Epoch 11/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0024 - rmse: 0.0494 - val_loss: 0.0056 - val_rmse: 0.0751
# Epoch 12/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0027 - rmse: 0.0509 - val_loss: 0.0025 - val_rmse: 0.0497
# Epoch 13/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0023 - rmse: 0.0472 - val_loss: 0.0025 - val_rmse: 0.0499
# Epoch 14/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0021 - rmse: 0.0459 - val_loss: 0.0023 - val_rmse: 0.0479
# Epoch 15/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0020 - rmse: 0.0448 - val_loss: 0.0027 - val_rmse: 0.0522
# Epoch 16/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0021 - rmse: 0.0453 - val_loss: 0.0027 - val_rmse: 0.0519
# Epoch 17/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0020 - rmse: 0.0447 - val_loss: 0.0048 - val_rmse: 0.0695
# Epoch 18/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0022 - rmse: 0.0466 - val_loss: 0.0024 - val_rmse: 0.0495
# Epoch 19/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0019 - rmse: 0.0438 - val_loss: 0.0022 - val_rmse: 0.0467
# Epoch 20/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0019 - rmse: 0.0429 - val_loss: 0.0022 - val_rmse: 0.0466
# Epoch 21/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0019 - rmse: 0.0430 - val_loss: 0.0022 - val_rmse: 0.0470
# Epoch 22/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0019 - rmse: 0.0431 - val_loss: 0.0026 - val_rmse: 0.0507
# Epoch 23/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0018 - rmse: 0.0427 - val_loss: 0.0020 - val_rmse: 0.0446
# Epoch 24/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0018 - rmse: 0.0416 - val_loss: 0.0021 - val_rmse: 0.0452
# Epoch 25/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0018 - rmse: 0.0420 - val_loss: 0.0022 - val_rmse: 0.0464
# Epoch 26/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0018 - rmse: 0.0415 - val_loss: 0.0023 - val_rmse: 0.0483
# Epoch 27/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0017 - rmse: 0.0411 - val_loss: 0.0038 - val_rmse: 0.0611
# Epoch 28/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0017 - rmse: 0.0414 - val_loss: 0.0020 - val_rmse: 0.0441
# Epoch 29/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0017 - rmse: 0.0402 - val_loss: 0.0022 - val_rmse: 0.0469
# Epoch 30/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0017 - rmse: 0.0407 - val_loss: 0.0020 - val_rmse: 0.0440
# Epoch 31/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0016 - rmse: 0.0397 - val_loss: 0.0020 - val_rmse: 0.0443
# Epoch 32/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0016 - rmse: 0.0398 - val_loss: 0.0018 - val_rmse: 0.0428
# Epoch 33/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0016 - rmse: 0.0401 - val_loss: 0.0021 - val_rmse: 0.0465
# Epoch 34/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0018 - val_rmse: 0.0427
# Epoch 35/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0019 - val_rmse: 0.0441
# Epoch 36/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0016 - rmse: 0.0394 - val_loss: 0.0019 - val_rmse: 0.0430
# Epoch 37/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0015 - rmse: 0.0381 - val_loss: 0.0017 - val_rmse: 0.0417
# Epoch 38/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0015 - rmse: 0.0381 - val_loss: 0.0019 - val_rmse: 0.0431
# Epoch 39/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0014 - rmse: 0.0372 - val_loss: 0.0017 - val_rmse: 0.0416
# Epoch 40/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0368 - val_loss: 0.0029 - val_rmse: 0.0543
# Epoch 41/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0373 - val_loss: 0.0019 - val_rmse: 0.0439
# Epoch 42/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0014 - rmse: 0.0369 - val_loss: 0.0016 - val_rmse: 0.0405
# Epoch 43/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0014 - rmse: 0.0366 - val_loss: 0.0016 - val_rmse: 0.0400
# Epoch 44/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0369 - val_loss: 0.0016 - val_rmse: 0.0405
# Epoch 45/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0369 - val_loss: 0.0018 - val_rmse: 0.0431
# Epoch 46/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0367 - val_loss: 0.0018 - val_rmse: 0.0424
# Epoch 47/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0375 - val_loss: 0.0017 - val_rmse: 0.0410
# Epoch 48/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0014 - rmse: 0.0368 - val_loss: 0.0017 - val_rmse: 0.0418
# Epoch 49/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0364 - val_loss: 0.0017 - val_rmse: 0.0417
# Epoch 50/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0013 - rmse: 0.0360 - val_loss: 0.0016 - val_rmse: 0.0400
# Epoch 51/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0357 - val_loss: 0.0016 - val_rmse: 0.0403
# Epoch 52/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0357 - val_loss: 0.0022 - val_rmse: 0.0470
# Epoch 53/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0362 - val_loss: 0.0018 - val_rmse: 0.0419
# Epoch 54/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0012 - rmse: 0.0350 - val_loss: 0.0016 - val_rmse: 0.0397
# Epoch 55/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0013 - rmse: 0.0355 - val_loss: 0.0016 - val_rmse: 0.0396
# Epoch 56/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0013 - rmse: 0.0357 - val_loss: 0.0016 - val_rmse: 0.0406
# Epoch 57/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0350 - val_loss: 0.0017 - val_rmse: 0.0409
# Epoch 58/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0016 - val_rmse: 0.0396
# Epoch 59/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0346 - val_loss: 0.0021 - val_rmse: 0.0454
# Epoch 60/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0013 - rmse: 0.0358 - val_loss: 0.0016 - val_rmse: 0.0395
# Epoch 61/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0020 - val_rmse: 0.0450
# Epoch 62/100
# 113/113 [==============================] - 1s 11ms/step - loss: 0.0013 - rmse: 0.0353 - val_loss: 0.0015 - val_rmse: 0.0387
# Epoch 63/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0345 - val_loss: 0.0016 - val_rmse: 0.0396
# Epoch 64/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0345 - val_loss: 0.0027 - val_rmse: 0.0515
# Epoch 65/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0013 - rmse: 0.0356 - val_loss: 0.0015 - val_rmse: 0.0390
# Epoch 66/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0012 - rmse: 0.0339 - val_loss: 0.0038 - val_rmse: 0.0610
# Epoch 67/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0018 - rmse: 0.0414 - val_loss: 0.0017 - val_rmse: 0.0409
# Epoch 68/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0013 - rmse: 0.0353 - val_loss: 0.0016 - val_rmse: 0.0400
# Epoch 69/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0345 - val_loss: 0.0015 - val_rmse: 0.0388
# Epoch 70/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0346 - val_loss: 0.0017 - val_rmse: 0.0407
# Epoch 71/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0342 - val_loss: 0.0016 - val_rmse: 0.0404
# Epoch 72/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0334 - val_loss: 0.0015 - val_rmse: 0.0394
# Epoch 73/100
# 113/113 [==============================] - 2s 16ms/step - loss: 0.0011 - rmse: 0.0334 - val_loss: 0.0015 - val_rmse: 0.0384
# Epoch 74/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0331 - val_loss: 0.0017 - val_rmse: 0.0409
# Epoch 75/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0332 - val_loss: 0.0015 - val_rmse: 0.0390
# Epoch 76/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0332 - val_loss: 0.0015 - val_rmse: 0.0393
# Epoch 77/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0328 - val_loss: 0.0015 - val_rmse: 0.0388
# Epoch 78/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0326 - val_loss: 0.0017 - val_rmse: 0.0419
# Epoch 79/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0011 - rmse: 0.0328 - val_loss: 0.0015 - val_rmse: 0.0383
# Epoch 80/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0011 - rmse: 0.0327 - val_loss: 0.0015 - val_rmse: 0.0383
# Epoch 81/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0325 - val_loss: 0.0015 - val_rmse: 0.0383
# Epoch 82/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0010 - rmse: 0.0323 - val_loss: 0.0015 - val_rmse: 0.0390
# Epoch 83/100
# 113/113 [==============================] - 1s 9ms/step - loss: 0.0011 - rmse: 0.0323 - val_loss: 0.0015 - val_rmse: 0.0391
# Epoch 84/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0010 - rmse: 0.0320 - val_loss: 0.0015 - val_rmse: 0.0386
# Epoch 85/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0324 - val_loss: 0.0015 - val_rmse: 0.0390
# Epoch 86/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0011 - rmse: 0.0327 - val_loss: 0.0015 - val_rmse: 0.0386
# Epoch 87/100
# 113/113 [==============================] - 1s 12ms/step - loss: 0.0011 - rmse: 0.0323 - val_loss: 0.0014 - val_rmse: 0.0381
# Epoch 88/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0010 - rmse: 0.0318 - val_loss: 0.0018 - val_rmse: 0.0428
# Epoch 89/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0010 - rmse: 0.0322 - val_loss: 0.0015 - val_rmse: 0.0386
# Epoch 90/100
# 113/113 [==============================] - 1s 11ms/step - loss: 0.0010 - rmse: 0.0315 - val_loss: 0.0014 - val_rmse: 0.0381
# Epoch 91/100
# 113/113 [==============================] - 1s 10ms/step - loss: 9.7121e-04 - rmse: 0.0311 - val_loss: 0.0015 - val_rmse: 0.0384
# Epoch 92/100
# 113/113 [==============================] - 1s 10ms/step - loss: 9.8066e-04 - rmse: 0.0315 - val_loss: 0.0033 - val_rmse: 0.0568
# Epoch 93/100
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0015 - val_rmse: 0.0383
# Epoch 94/100
# 113/113 [==============================] - 1s 11ms/step - loss: 9.9257e-04 - rmse: 0.0312 - val_loss: 0.0014 - val_rmse: 0.0374
# Epoch 95/100
# 113/113 [==============================] - 1s 10ms/step - loss: 9.3539e-04 - rmse: 0.0303 - val_loss: 0.0015 - val_rmse: 0.0384
# Epoch 96/100
# 113/113 [==============================] - 1s 11ms/step - loss: 9.2225e-04 - rmse: 0.0303 - val_loss: 0.0014 - val_rmse: 0.0373
# Epoch 97/100
# 113/113 [==============================] - 1s 9ms/step - loss: 9.2164e-04 - rmse: 0.0301 - val_loss: 0.0015 - val_rmse: 0.0383
# Epoch 98/100
# 113/113 [==============================] - 1s 10ms/step - loss: 8.9398e-04 - rmse: 0.0298 - val_loss: 0.0015 - val_rmse: 0.0385
# Epoch 99/100
# 113/113 [==============================] - 1s 10ms/step - loss: 8.9449e-04 - rmse: 0.0296 - val_loss: 0.0014 - val_rmse: 0.0376
# Epoch 100/100
# 113/113 [==============================] - 1s 10ms/step - loss: 8.8256e-04 - rmse: 0.0297 - val_loss: 0.0015 - val_rmse: 0.0385
#
# elapsed time (training): 127.354 seconds

# %%
model.load_weights(fname_param)
score = model.evaluate(
    X_test, Y_test, batch_size=Y_test.shape[0], verbose=0)
print('Test score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
        (score[0], score[1], score[1] * (mmn._max - mmn._min) / 2. * m_factor))
# Out:
# Test score: 0.001339 rmse (norm): 0.036589 rmse (real): 6.140291
