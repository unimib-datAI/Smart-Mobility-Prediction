# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/3D-CLoST/3D-CLoST/ST-ResNet')

# %%
# !pip install bayesian-optimization
# Out:
# ...
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=3d9ee938b1e71dec5628231c2d11205eb6960724801f5d51d5a7fbc54f9e28a7
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# ...

# %%
# !python main_taxiNYC.py
# Out:
# 2020-12-06 17:26:52.617267: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data...
# main_taxiNYC.py:78: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   num = int(f['num'].value)
# main_taxiNYC.py:81: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   X_train.append(f['X_train_%i' % i].value)
# main_taxiNYC.py:82: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   X_test.append(f['X_test_%i' % i].value)
# main_taxiNYC.py:83: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   Y_train = f['Y_train'].value
# main_taxiNYC.py:84: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   Y_test = f['Y_test'].value
# main_taxiNYC.py:85: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# ...
