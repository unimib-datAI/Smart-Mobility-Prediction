# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
import os
os.chdir('./drive/My Drive/TESI/ST-ResNet')
# Out:
# Mounted at /content/drive/

# %%
from __future__ import print_function
import os
import sys
import pickle
import time
import numpy as np
import h5py

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint

from deepst.models.STResNet import stresnet
import deepst.metrics as metrics
from deepst.datasets import TaxiBJ

# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.4.3
# 2.3.0
# Num GPUs Available:  1

# %%
np.random.seed(1337)  # for reproducibility

# parameters
DATAPATH = '../data'  # data path, you may set your own data path with the global envirmental variable DATAPATH
CACHEDATA = True  # cache data or NOT
path_cache = os.path.join(DATAPATH, 'CACHE', 'ST-ResNet')  # cache path
nb_epoch = 100  # number of epoch at training stage
# nb_epoch_cont = 100  # number of epoch at training (cont) stage
batch_size = 32  # batch size
T = 48  # number of time intervals in one day
lr = 0.0002  # learning rate
len_closeness = 3  # length of closeness dependent sequence
len_period = 1  # length of peroid dependent sequence
len_trend = 1  # length of trend dependent sequence
nb_residual_unit = 12 # paper says 12 for taxiBJ

nb_flow = 2  # there are two types of flows: inflow and outflow
# divide data into two subsets: Train & Test, of which the test set is the
# last 4 weeks
days_test = 7 * 4
len_test = T * days_test
map_height, map_width = 32, 32  # grid size
path_result = 'RET'
path_model = 'MODEL'

# %%
if os.path.isdir(path_result) is False:
    os.mkdir(path_result)
if os.path.isdir(path_model) is False:
    os.mkdir(path_model)
if CACHEDATA and os.path.isdir(path_cache) is False:
    os.mkdir(path_cache)

# %%
def build_model(external_dim):
    c_conf = (len_closeness, nb_flow, map_height,
              map_width) if len_closeness > 0 else None
    p_conf = (len_period, nb_flow, map_height,
              map_width) if len_period > 0 else None
    t_conf = (len_trend, nb_flow, map_height,
              map_width) if len_trend > 0 else None
    model = stresnet(c_conf=c_conf, p_conf=p_conf, t_conf=t_conf,
                     external_dim=external_dim, nb_residual_unit=nb_residual_unit)
    adam = Adam(lr=lr)
    model.compile(loss='mse', optimizer=adam, metrics=[metrics.rmse])
    model.summary()
    # from keras.utils.visualize_util import plot
    # plot(model, to_file='model.png', show_shapes=True)
    return model

# %%
def read_cache(fname):
    mmn = pickle.load(open('preprocessing_taxibj.pkl', 'rb'))

    f = h5py.File(fname, 'r')
    num = int(f['num'].value)
    X_train, Y_train, X_test, Y_test = [], [], [], []
    for i in range(num):
        X_train.append(f['X_train_%i' % i].value)
        X_test.append(f['X_test_%i' % i].value)
    Y_train = f['Y_train'].value
    Y_test = f['Y_test'].value
    external_dim = f['external_dim'].value
    timestamp_train = f['T_train'].value
    timestamp_test = f['T_test'].value
    f.close()

    return X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test

# %%
def cache(fname, X_train, Y_train, X_test, Y_test, external_dim, timestamp_train, timestamp_test):
    h5 = h5py.File(fname, 'w')
    h5.create_dataset('num', data=len(X_train))

    for i, data in enumerate(X_train):
        h5.create_dataset('X_train_%i' % i, data=data)
    # for i, data in enumerate(Y_train):
    for i, data in enumerate(X_test):
        h5.create_dataset('X_test_%i' % i, data=data)
    h5.create_dataset('Y_train', data=Y_train)
    h5.create_dataset('Y_test', data=Y_test)
    external_dim = -1 if external_dim is None else int(external_dim)
    h5.create_dataset('external_dim', data=external_dim)
    h5.create_dataset('T_train', data=timestamp_train)
    h5.create_dataset('T_test', data=timestamp_test)
    h5.close()

# %%
print("loading data...")
ts = time.time()
fname = os.path.join(path_cache, 'TaxiBJ_C{}_P{}_T{}.h5'.format(
    len_closeness, len_period, len_trend))
if os.path.exists(fname) and CACHEDATA:
    X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test = read_cache(
        fname)
    print("load %s successfully" % fname)
else:
    X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test = TaxiBJ.load_data(
        T=T, nb_flow=nb_flow, len_closeness=len_closeness, len_period=len_period, len_trend=len_trend, len_test=len_test,
        preprocess_name='preprocessing_taxibj.pkl', meta_data=True, meteorol_data=False, holiday_data=False, datapath=DATAPATH)
    if CACHEDATA:
        cache(fname, X_train, Y_train, X_test, Y_test,
              external_dim, timestamp_train, timestamp_test)

print("\n days (test): ", [v[:8] for v in timestamp_test[0::T]])
print("\nelapsed time (loading data): %.3f seconds\n" % (time.time() - ts))

print('=' * 10)
# Out:
# loading data...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# load ../data/CACHE/ST-ResNet/TaxiBJ_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20160310', b'20160311', b'20160312', b'20160313', b'20160314', b'20160315', b'20160316', b'20160317', b'20160318', b'20160319', b'20160320', b'20160321', b'20160322', b'20160325', b'20160326', b'20160327', b'20160328', b'20160329', b'20160331', b'20160401', b'20160402', b'20160403', b'20160404', b'20160405', b'20160406', b'20160407', b'20160408', b'20160409']
#
# elapsed time (loading data): 9.498 seconds
#
# ==========
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
#from deepst.datasets import stat; stat('BJ16_M32x32_T30_InOut.h5')
f = h5py.File('../data/TaxiBJ/BJ15_M32x32_T30_InOut.h5', 'r')
print(len(f['date']))
# print(f['data'][1][0][0])

print(len(X_train))
print(len(X_train[0]))
print(len(X_train[0][0]))
xtrain_np = np.array(X_train[0], dtype=np.float32)
print(xtrain_np.shape)
print(len(Y_train))
ytrain_np = np.array(Y_train, dtype=np.float32)
print(ytrain_np.shape)
print(len(timestamp_train))
print(len(timestamp_test))
print(len(X_test))
X_train[0].mean()
# Out:
# 5596
# 4
# 13728
# 6
# (13728, 6, 32, 32)
# 13728
# (13728, 2, 32, 32)
# 13728
# 1344
# 4
# -0.8367472361048437

# %%
print("compiling model...")
print(
    "**at the first time, it takes a few minites to compile if you use [Theano] as the backend**")
ts = time.time()
model = build_model(external_dim)
hyperparams_name = 'TaxiBJ.c{}.p{}.t{}.resunit{}.lr{}'.format(
    len_closeness, len_period, len_trend, nb_residual_unit, lr)
fname_param = os.path.join('MODEL', '{}.best.h5'.format(hyperparams_name))

early_stopping = EarlyStopping(monitor='val_rmse', patience=2, mode='min')
model_checkpoint = ModelCheckpoint(
    fname_param, monitor='val_rmse', verbose=0, save_best_only=True, mode='min')

print("\nelapsed time (compiling model): %.3f seconds\n" %
      (time.time() - ts))

print('=' * 10)
# Out:
# compiling model...
# **at the first time, it takes a few minites to compile if you use [Theano] as the backend**
# (None, 2, 32, 32)
# (None, 2, 32, 32)
# (None, 2, 32, 32)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6, 32, 32)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2, 32, 32)]  0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 2, 32, 32)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 32, 32)   3520        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 32, 32)   1216        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 32, 32)   1216        input_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 32, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 32, 32)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 64, 32, 32)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 32, 32)   36928       activation[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 32, 32)   36928       activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 32, 32)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 32, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 64, 32, 32)   0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 32, 32)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 32, 32)   36928       activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 32, 32)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 32, 32)   0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 32, 32)   0           conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 64, 32, 32)   0           conv2d_52[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 32, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 32, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 64, 32, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 32, 32)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 32, 32)   36928       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 32, 32)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 32, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 64, 32, 32)   0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 32, 32)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 32, 32)   36928       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 32, 32)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 32, 32)   0           add[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 32, 32)   0           add_12[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 64, 32, 32)   0           add_24[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 32, 32)   0           add_1[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 32, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 64, 32, 32)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 32, 32)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 32, 32)   36928       activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 32, 32)   36928       activation_54[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 32, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 64, 32, 32)   0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 32, 32)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 32, 32)   36928       activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 32, 32)   36928       activation_55[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 32, 32)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 32, 32)   0           add_13[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 64, 32, 32)   0           add_25[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 32, 32)   0           add_2[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 32, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 64, 32, 32)   0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 32, 32)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 32, 32)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 32, 32)   36928       activation_56[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 32, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 32, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64, 32, 32)   0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 32, 32)   36928       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 32, 32)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 32, 32)   36928       activation_57[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 32, 32)   0           add_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 32, 32)   0           add_14[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 64, 32, 32)   0           add_26[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 32, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 32, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 64, 32, 32)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 32, 32)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 32, 32)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 32, 32)   36928       activation_58[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 32, 32)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 32, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 64, 32, 32)   0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 32, 32)   36928       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 32, 32)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 32, 32)   36928       activation_59[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 32, 32)   0           add_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 32, 32)   0           add_15[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 64, 32, 32)   0           add_27[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 32, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 32, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 64, 32, 32)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 32, 32)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 32, 32)   36928       activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 32, 32)   36928       activation_60[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 64, 32, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 32, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 64, 32, 32)   0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 32, 32)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 32, 32)   36928       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 32, 32)   36928       activation_61[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 32, 32)   0           add_4[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 32, 32)   0           add_16[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 64, 32, 32)   0           add_28[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 32, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 64, 32, 32)   0           add_17[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 64, 32, 32)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 32, 32)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 32, 32)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 64, 32, 32)   36928       activation_62[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 32, 32)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64, 32, 32)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 64, 32, 32)   0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 32, 32)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 32, 32)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 64, 32, 32)   36928       activation_63[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 32, 32)   0           add_5[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 32, 32)   0           add_17[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 64, 32, 32)   0           add_29[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 32, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 64, 32, 32)   0           add_18[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 64, 32, 32)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 32, 32)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 32, 32)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 64, 32, 32)   36928       activation_64[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 32, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 32, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 64, 32, 32)   0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 32, 32)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 32, 32)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 32, 32)   36928       activation_65[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 32, 32)   0           add_6[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 32, 32)   0           add_18[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 64, 32, 32)   0           add_30[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 32, 32)   0           add_7[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 32, 32)   0           add_19[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 64, 32, 32)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 32, 32)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 32, 32)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 32, 32)   36928       activation_66[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 32, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 32, 32)   0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 64, 32, 32)   0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 32, 32)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 32, 32)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 32, 32)   36928       activation_67[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 32, 32)   0           add_7[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 64, 32, 32)   0           add_19[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 64, 32, 32)   0           add_31[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 32, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 32, 32)   0           add_20[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 64, 32, 32)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 32, 32)   36928       activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 32, 32)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 32, 32)   36928       activation_68[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 32, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 64, 32, 32)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 64, 32, 32)   0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 32, 32)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 32, 32)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 32, 32)   36928       activation_69[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 32, 32)   0           add_8[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 32, 32)   0           add_20[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 64, 32, 32)   0           add_32[0][0]
#                                                                  conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 32, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 64, 32, 32)   0           add_21[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 64, 32, 32)   0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 32, 32)   36928       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 64, 32, 32)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 32, 32)   36928       activation_70[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 32, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 32, 32)   0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 64, 32, 32)   0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 32, 32)   36928       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 32, 32)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 32, 32)   36928       activation_71[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 32, 32)   0           add_9[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 64, 32, 32)   0           add_21[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 64, 32, 32)   0           add_33[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 32, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 32, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 64, 32, 32)   0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 32, 32)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 32, 32)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 32, 32)   36928       activation_72[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 32, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 32, 32)   0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 64, 32, 32)   0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 32, 32)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 32, 32)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 32, 32)   36928       activation_73[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 32, 32)   0           add_10[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 64, 32, 32)   0           add_22[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 64, 32, 32)   0           add_34[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           90          input_4[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 32, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 64, 32, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 64, 32, 32)   0           add_35[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 10)           0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 32, 32)    1154        activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 2, 32, 32)    1154        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 2, 32, 32)    1154        activation_74[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         22528       activation_75[0][0]
# __________________________________________________________________________________________________
# i_layer (iLayer)                (None, 2, 32, 32)    2048        conv2d_25[0][0]
# __________________________________________________________________________________________________
# i_layer_1 (iLayer)              (None, 2, 32, 32)    2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# i_layer_2 (iLayer)              (None, 2, 32, 32)    2048        conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 2048)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 2, 32, 32)    0           i_layer[0][0]
#                                                                  i_layer_1[0][0]
#                                                                  i_layer_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 2, 32, 32)    0           activation_76[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 2, 32, 32)    0           add_36[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 2, 32, 32)    0           add_37[0][0]
# ==================================================================================================
# Total params: 2,696,992
# Trainable params: 2,696,992
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# elapsed time (compiling model): 5.419 seconds
#
# ==========

# %%
print("training model...")
ts = time.time()
history = model.fit(X_train, Y_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    validation_split=0.1,
                    callbacks=[model_checkpoint],
                    # callbacks=[early_stopping, model_checkpoint],
                    verbose=1)
model.save_weights(os.path.join(
    'MODEL', '{}.h5'.format(hyperparams_name)), overwrite=True)
pickle.dump((history.history), open(os.path.join(
    path_result, '{}.history.pkl'.format(hyperparams_name)), 'wb'))
print("\nelapsed time (training): %.3f seconds\n" % (time.time() - ts))
# Out:
# training model...
# Epoch 1/100
# 387/387 [==============================] - 57s 147ms/step - loss: 0.0247 - rmse: 0.1292 - val_loss: 0.0044 - val_rmse: 0.0650
# Epoch 2/100
# 387/387 [==============================] - 57s 148ms/step - loss: 0.0030 - rmse: 0.0540 - val_loss: 0.0026 - val_rmse: 0.0495
# Epoch 3/100
# 387/387 [==============================] - 58s 149ms/step - loss: 0.0022 - rmse: 0.0463 - val_loss: 0.0022 - val_rmse: 0.0464
# Epoch 4/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0018 - rmse: 0.0416 - val_loss: 0.0018 - val_rmse: 0.0415
# Epoch 5/100
# 387/387 [==============================] - 57s 147ms/step - loss: 0.0016 - rmse: 0.0395 - val_loss: 0.0022 - val_rmse: 0.0463
# Epoch 6/100
# 387/387 [==============================] - 57s 147ms/step - loss: 0.0015 - rmse: 0.0380 - val_loss: 0.0019 - val_rmse: 0.0435
# Epoch 7/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0013 - rmse: 0.0361 - val_loss: 0.0014 - val_rmse: 0.0369
# Epoch 8/100
# 387/387 [==============================] - 57s 147ms/step - loss: 0.0012 - rmse: 0.0348 - val_loss: 0.0078 - val_rmse: 0.0878
# Epoch 9/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0013 - rmse: 0.0354 - val_loss: 0.0011 - val_rmse: 0.0325
# Epoch 10/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0011 - rmse: 0.0328 - val_loss: 0.0011 - val_rmse: 0.0320
# Epoch 11/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0011 - rmse: 0.0333 - val_loss: 0.0010 - val_rmse: 0.0309
# Epoch 12/100
# 387/387 [==============================] - 57s 147ms/step - loss: 0.0011 - rmse: 0.0323 - val_loss: 0.0013 - val_rmse: 0.0348
# Epoch 13/100
# 387/387 [==============================] - 58s 149ms/step - loss: 0.0010 - rmse: 0.0318 - val_loss: 9.8571e-04 - val_rmse: 0.0308
# Epoch 14/100
# 387/387 [==============================] - 58s 150ms/step - loss: 0.0010 - rmse: 0.0317 - val_loss: 8.9758e-04 - val_rmse: 0.0292
# Epoch 15/100
# 387/387 [==============================] - 57s 147ms/step - loss: 9.8162e-04 - rmse: 0.0309 - val_loss: 0.0012 - val_rmse: 0.0327
# Epoch 16/100
# 387/387 [==============================] - 57s 147ms/step - loss: 9.7193e-04 - rmse: 0.0307 - val_loss: 0.0010 - val_rmse: 0.0307
# Epoch 17/100
# 387/387 [==============================] - 57s 147ms/step - loss: 9.4438e-04 - rmse: 0.0303 - val_loss: 9.1759e-04 - val_rmse: 0.0297
# Epoch 18/100
# 387/387 [==============================] - 58s 150ms/step - loss: 9.3875e-04 - rmse: 0.0302 - val_loss: 7.8938e-04 - val_rmse: 0.0273
# Epoch 19/100
# 387/387 [==============================] - 57s 147ms/step - loss: 9.5390e-04 - rmse: 0.0304 - val_loss: 8.1428e-04 - val_rmse: 0.0279
# Epoch 20/100
# 387/387 [==============================] - 57s 147ms/step - loss: 9.0145e-04 - rmse: 0.0296 - val_loss: 8.8704e-04 - val_rmse: 0.0286
# Epoch 21/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.9895e-04 - rmse: 0.0295 - val_loss: 8.7235e-04 - val_rmse: 0.0290
# Epoch 22/100
# 387/387 [==============================] - 58s 150ms/step - loss: 8.8744e-04 - rmse: 0.0293 - val_loss: 7.5406e-04 - val_rmse: 0.0267
# Epoch 23/100
# 387/387 [==============================] - 58s 149ms/step - loss: 8.7562e-04 - rmse: 0.0291 - val_loss: 7.4092e-04 - val_rmse: 0.0266
# Epoch 24/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.7355e-04 - rmse: 0.0291 - val_loss: 9.2834e-04 - val_rmse: 0.0293
# Epoch 25/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.7090e-04 - rmse: 0.0291 - val_loss: 8.0023e-04 - val_rmse: 0.0273
# Epoch 26/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.5334e-04 - rmse: 0.0287 - val_loss: 7.9077e-04 - val_rmse: 0.0275
# Epoch 27/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.4162e-04 - rmse: 0.0286 - val_loss: 7.8572e-04 - val_rmse: 0.0275
# Epoch 28/100
# 387/387 [==============================] - 58s 150ms/step - loss: 8.4724e-04 - rmse: 0.0286 - val_loss: 7.2007e-04 - val_rmse: 0.0261
# Epoch 29/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.2278e-04 - rmse: 0.0282 - val_loss: 0.0011 - val_rmse: 0.0321
# Epoch 30/100
# 387/387 [==============================] - 57s 148ms/step - loss: 8.3288e-04 - rmse: 0.0284 - val_loss: 7.1543e-04 - val_rmse: 0.0261
# Epoch 31/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.1689e-04 - rmse: 0.0281 - val_loss: 7.1778e-04 - val_rmse: 0.0262
# Epoch 32/100
# 387/387 [==============================] - 58s 150ms/step - loss: 8.0868e-04 - rmse: 0.0280 - val_loss: 6.9102e-04 - val_rmse: 0.0256
# Epoch 33/100
# 387/387 [==============================] - 58s 150ms/step - loss: 8.1232e-04 - rmse: 0.0280 - val_loss: 6.6431e-04 - val_rmse: 0.0249
# Epoch 34/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.9069e-04 - rmse: 0.0277 - val_loss: 0.0011 - val_rmse: 0.0324
# Epoch 35/100
# 387/387 [==============================] - 57s 147ms/step - loss: 8.0496e-04 - rmse: 0.0279 - val_loss: 6.6277e-04 - val_rmse: 0.0250
# Epoch 36/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.9236e-04 - rmse: 0.0277 - val_loss: 7.7982e-04 - val_rmse: 0.0274
# Epoch 37/100
# 387/387 [==============================] - 58s 150ms/step - loss: 7.8606e-04 - rmse: 0.0275 - val_loss: 6.4989e-04 - val_rmse: 0.0247
# Epoch 38/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.8329e-04 - rmse: 0.0275 - val_loss: 7.7797e-04 - val_rmse: 0.0273
# Epoch 39/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.7772e-04 - rmse: 0.0275 - val_loss: 7.1812e-04 - val_rmse: 0.0259
# Epoch 40/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.6767e-04 - rmse: 0.0272 - val_loss: 6.5036e-04 - val_rmse: 0.0247
# Epoch 41/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.8638e-04 - rmse: 0.0276 - val_loss: 8.2913e-04 - val_rmse: 0.0279
# Epoch 42/100
# 387/387 [==============================] - 58s 149ms/step - loss: 7.6916e-04 - rmse: 0.0272 - val_loss: 6.2565e-04 - val_rmse: 0.0242
# Epoch 43/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.7412e-04 - rmse: 0.0273 - val_loss: 6.4726e-04 - val_rmse: 0.0247
# Epoch 44/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.5098e-04 - rmse: 0.0269 - val_loss: 7.1969e-04 - val_rmse: 0.0262
# Epoch 45/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.5249e-04 - rmse: 0.0270 - val_loss: 6.2838e-04 - val_rmse: 0.0243
# Epoch 46/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.5415e-04 - rmse: 0.0270 - val_loss: 6.9107e-04 - val_rmse: 0.0254
# Epoch 47/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.4279e-04 - rmse: 0.0268 - val_loss: 6.3361e-04 - val_rmse: 0.0244
# Epoch 48/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.3322e-04 - rmse: 0.0266 - val_loss: 7.4633e-04 - val_rmse: 0.0268
# Epoch 49/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.3970e-04 - rmse: 0.0267 - val_loss: 6.4670e-04 - val_rmse: 0.0247
# Epoch 50/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.3702e-04 - rmse: 0.0267 - val_loss: 6.7467e-04 - val_rmse: 0.0251
# Epoch 51/100
# 387/387 [==============================] - 58s 150ms/step - loss: 7.3043e-04 - rmse: 0.0266 - val_loss: 6.1380e-04 - val_rmse: 0.0240
# Epoch 52/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.2816e-04 - rmse: 0.0265 - val_loss: 6.1799e-04 - val_rmse: 0.0241
# Epoch 53/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.3048e-04 - rmse: 0.0266 - val_loss: 6.5971e-04 - val_rmse: 0.0250
# Epoch 54/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.2733e-04 - rmse: 0.0265 - val_loss: 7.1279e-04 - val_rmse: 0.0261
# Epoch 55/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.1463e-04 - rmse: 0.0263 - val_loss: 6.1393e-04 - val_rmse: 0.0240
# Epoch 56/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.0801e-04 - rmse: 0.0262 - val_loss: 6.4299e-04 - val_rmse: 0.0246
# Epoch 57/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.1921e-04 - rmse: 0.0264 - val_loss: 7.3073e-04 - val_rmse: 0.0264
# Epoch 58/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.9942e-04 - rmse: 0.0260 - val_loss: 7.6643e-04 - val_rmse: 0.0269
# Epoch 59/100
# 387/387 [==============================] - 57s 147ms/step - loss: 7.2002e-04 - rmse: 0.0264 - val_loss: 6.4422e-04 - val_rmse: 0.0248
# Epoch 60/100
# 387/387 [==============================] - 57s 148ms/step - loss: 7.0044e-04 - rmse: 0.0260 - val_loss: 6.1642e-04 - val_rmse: 0.0241
# Epoch 61/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.9637e-04 - rmse: 0.0260 - val_loss: 6.1593e-04 - val_rmse: 0.0242
# Epoch 62/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.9570e-04 - rmse: 0.0260 - val_loss: 6.2230e-04 - val_rmse: 0.0243
# Epoch 63/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.8674e-04 - rmse: 0.0258 - val_loss: 6.2207e-04 - val_rmse: 0.0242
# Epoch 64/100
# 387/387 [==============================] - 58s 150ms/step - loss: 6.9314e-04 - rmse: 0.0259 - val_loss: 5.9838e-04 - val_rmse: 0.0237
# Epoch 65/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.8529e-04 - rmse: 0.0258 - val_loss: 6.4030e-04 - val_rmse: 0.0246
# Epoch 66/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.6993e-04 - rmse: 0.0255 - val_loss: 6.1982e-04 - val_rmse: 0.0241
# Epoch 67/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.8929e-04 - rmse: 0.0259 - val_loss: 6.1398e-04 - val_rmse: 0.0240
# Epoch 68/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.8991e-04 - rmse: 0.0258 - val_loss: 6.0666e-04 - val_rmse: 0.0238
# Epoch 69/100
# 387/387 [==============================] - 58s 150ms/step - loss: 6.7553e-04 - rmse: 0.0255 - val_loss: 5.8986e-04 - val_rmse: 0.0235
# Epoch 70/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.7045e-04 - rmse: 0.0255 - val_loss: 6.1114e-04 - val_rmse: 0.0239
# Epoch 71/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.8343e-04 - rmse: 0.0257 - val_loss: 6.1566e-04 - val_rmse: 0.0241
# Epoch 72/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.6060e-04 - rmse: 0.0253 - val_loss: 6.0070e-04 - val_rmse: 0.0238
# Epoch 73/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.5574e-04 - rmse: 0.0252 - val_loss: 5.9020e-04 - val_rmse: 0.0235
# Epoch 74/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.5374e-04 - rmse: 0.0252 - val_loss: 6.1170e-04 - val_rmse: 0.0241
# Epoch 75/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.5184e-04 - rmse: 0.0251 - val_loss: 6.5709e-04 - val_rmse: 0.0249
# Epoch 76/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4373e-04 - rmse: 0.0250 - val_loss: 6.1583e-04 - val_rmse: 0.0241
# Epoch 77/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4301e-04 - rmse: 0.0250 - val_loss: 6.0938e-04 - val_rmse: 0.0240
# Epoch 78/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4027e-04 - rmse: 0.0250 - val_loss: 6.9951e-04 - val_rmse: 0.0259
# Epoch 79/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4510e-04 - rmse: 0.0251 - val_loss: 0.0010 - val_rmse: 0.0319
# Epoch 80/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4455e-04 - rmse: 0.0251 - val_loss: 6.5710e-04 - val_rmse: 0.0249
# Epoch 81/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.2472e-04 - rmse: 0.0247 - val_loss: 9.3474e-04 - val_rmse: 0.0302
# Epoch 82/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4502e-04 - rmse: 0.0251 - val_loss: 6.6065e-04 - val_rmse: 0.0251
# Epoch 83/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.2748e-04 - rmse: 0.0247 - val_loss: 7.3976e-04 - val_rmse: 0.0265
# Epoch 84/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.2577e-04 - rmse: 0.0247 - val_loss: 6.1113e-04 - val_rmse: 0.0241
# Epoch 85/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.1951e-04 - rmse: 0.0246 - val_loss: 6.1343e-04 - val_rmse: 0.0242
# Epoch 86/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.5022e-04 - rmse: 0.0252 - val_loss: 6.8257e-04 - val_rmse: 0.0256
# Epoch 87/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.3201e-04 - rmse: 0.0248 - val_loss: 5.9428e-04 - val_rmse: 0.0236
# Epoch 88/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.0197e-04 - rmse: 0.0242 - val_loss: 6.1413e-04 - val_rmse: 0.0242
# Epoch 89/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.4003e-04 - rmse: 0.0250 - val_loss: 5.9964e-04 - val_rmse: 0.0239
# Epoch 90/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.1797e-04 - rmse: 0.0246 - val_loss: 6.2903e-04 - val_rmse: 0.0245
# Epoch 91/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.9407e-04 - rmse: 0.0241 - val_loss: 6.0096e-04 - val_rmse: 0.0239
# Epoch 92/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.9981e-04 - rmse: 0.0242 - val_loss: 6.2454e-04 - val_rmse: 0.0245
# Epoch 93/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.9726e-04 - rmse: 0.0242 - val_loss: 7.4251e-04 - val_rmse: 0.0268
# Epoch 94/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.9738e-04 - rmse: 0.0242 - val_loss: 5.9160e-04 - val_rmse: 0.0238
# Epoch 95/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.8479e-04 - rmse: 0.0240 - val_loss: 6.1206e-04 - val_rmse: 0.0240
# Epoch 96/100
# 387/387 [==============================] - 58s 149ms/step - loss: 5.9482e-04 - rmse: 0.0241 - val_loss: 5.7813e-04 - val_rmse: 0.0233
# Epoch 97/100
# 387/387 [==============================] - 57s 147ms/step - loss: 6.1571e-04 - rmse: 0.0245 - val_loss: 5.9437e-04 - val_rmse: 0.0237
# Epoch 98/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.7740e-04 - rmse: 0.0238 - val_loss: 6.1605e-04 - val_rmse: 0.0243
# Epoch 99/100
# 387/387 [==============================] - 57s 147ms/step - loss: 5.8083e-04 - rmse: 0.0239 - val_loss: 6.2055e-04 - val_rmse: 0.0243
# Epoch 100/100
# 387/387 [==============================] - 57s 146ms/step - loss: 5.5876e-04 - rmse: 0.0234 - val_loss: 6.1825e-04 - val_rmse: 0.0243
#
# elapsed time (training): 5727.465 seconds

# %%
print('evaluating using the model that has the best loss on the valid set')

model.load_weights(fname_param)
score = model.evaluate(
    X_test, Y_test, batch_size=Y_test.shape[0], verbose=0)
print('Test score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
        (score[0], score[1], score[1] * (1292 - mmn._min) / 2.))
# Out:
# evaluating using the model that has the best loss on the valid set
# Test score: 0.000695 rmse (norm): 0.026367 rmse (real): 17.033243
