# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
import os
os.chdir('./drive/My Drive/TESI/STAR')
# Out:
# Mounted at /content/drive/

# %%
from __future__ import print_function
import os
import _pickle as pickle
import numpy as np
import math
import h5py

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint,TensorBoard, LearningRateScheduler
from star.model import *
import star.metrics as metrics
from star import BikeNYC

np.random.seed(1337)  # for reproducibility

# %%
# parameters
DATAPATH = '../data' 
nb_epoch = 100  # number of epoch at training stage
# nb_epoch_cont = 150  # number of epoch at training (cont) stage
batch_size = 16  # batch size
T = 24  # number of time intervals in one day
CACHEDATA = True  # cache data or NOT

lr = 0.00015  # learning rate
len_closeness = 3  # length of closeness dependent sequence
len_period = 1  # length of peroid dependent sequence
len_trend = 1  # length of trend dependent sequence
nb_residual_unit = 2   # number of residual units

nb_flow = 2  # there are two types of flows: new-flow and end-flow
# divide data into two subsets: Train & Test, of which the test set is the
# last 10 days
days_test = 10
len_test = T*days_test
len_val = 2*len_test

map_height, map_width = 16, 8  # grid size
# For NYC Bike data, there are 81 available grid-based areas, each of
# which includes at least ONE bike station. Therefore, we modify the final
# RMSE by multiplying the following factor (i.e., factor).
nb_area = 81
m_factor = math.sqrt(1. * map_height * map_width / nb_area)
print('factor: ', m_factor)

path_cache = os.path.join(DATAPATH, 'CACHE', 'STAR')  # cache path
path_result = 'RET'
path_model = 'MODEL'
if os.path.isdir(path_result) is False:
    os.mkdir(path_result)
if os.path.isdir(path_model) is False:
    os.mkdir(path_model)
if CACHEDATA and os.path.isdir(path_cache) is False:
    os.mkdir(path_cache)
# Out:
# factor:  1.2570787221094177

# %%
def build_model(external_dim, save_model_pic=False):
    c_conf = (len_closeness, nb_flow, map_height,
              map_width) if len_closeness > 0 else None
    p_conf = (len_period, nb_flow, map_height,
              map_width) if len_period > 0 else None
    t_conf = (len_trend, nb_flow, map_height,
              map_width) if len_trend > 0 else None

    model = STAR(c_conf=c_conf, p_conf=p_conf, t_conf=t_conf,
                     external_dim=external_dim, nb_residual_unit=nb_residual_unit)
    adam = Adam(lr=lr)
    model.compile(loss='mse', optimizer=adam, metrics=[metrics.rmse])
    # model.summary()
    if (save_model_pic):
        from keras.utils.vis_utils import plot_model
        plot_model(model, to_file='BikeNYC_model.png', show_shapes=True)

    return model

# %%
def read_cache(fname):
    mmn = pickle.load(open('preprocessing_nyc.pkl', 'rb'))

    f = h5py.File(fname, 'r')
    num = int(f['num'].value)
    X_train_all, Y_train_all, X_train, Y_train, X_val, Y_val, X_test, Y_test = [], [], [], [], [], [], [], []
    for i in range(num):
        X_train_all.append(f['X_train_all_%i' % i].value)
        X_train.append(f['X_train_%i' % i].value)
        X_val.append(f['X_val_%i' % i].value)
        X_test.append(f['X_test_%i' % i].value)
    Y_train_all = f['Y_train_all'].value
    Y_train = f['Y_train'].value
    Y_val = f['Y_val'].value
    Y_test = f['Y_test'].value
    external_dim = f['external_dim'].value
    timestamp_train_all = f['T_train_all'].value
    timestamp_train = f['T_train'].value
    timestamp_val = f['T_val'].value
    timestamp_test = f['T_test'].value
    f.close()

    return X_train_all, Y_train_all, X_train, Y_train, X_val, Y_val, X_test, Y_test, mmn, external_dim, timestamp_train_all, timestamp_train, timestamp_val, timestamp_test

def cache(fname, X_train_all, Y_train_all, X_train, Y_train, X_val, Y_val, X_test, Y_test, external_dim, timestamp_train_all, timestamp_train, timestamp_val, timestamp_test):
    h5 = h5py.File(fname, 'w')
    h5.create_dataset('num', data=len(X_train_all))

    for i, data in enumerate(X_train_all):
        h5.create_dataset('X_train_all_%i' % i, data=data)
    for i, data in enumerate(X_train):
        h5.create_dataset('X_train_%i' % i, data=data)
    for i, data in enumerate(X_val):
        h5.create_dataset('X_val_%i' % i, data=data)
    # for i, data in enumerate(Y_train):
    for i, data in enumerate(X_test):
        h5.create_dataset('X_test_%i' % i, data=data)

    h5.create_dataset('Y_train_all', data=Y_train_all)
    h5.create_dataset('Y_train', data=Y_train)
    h5.create_dataset('Y_val', data=Y_val)
    h5.create_dataset('Y_test', data=Y_test)
    external_dim = -1 if external_dim is None else int(external_dim)
    h5.create_dataset('external_dim', data=external_dim)
    h5.create_dataset('T_train_all', data=timestamp_train_all)
    h5.create_dataset('T_train', data=timestamp_train)
    h5.create_dataset('T_val', data=timestamp_val)
    h5.create_dataset('T_test', data=timestamp_test)
    h5.close()

def lrschedule(epoch):
    if epoch <= 25:
        return 0.0002
    elif epoch <= 50:
        return 0.00015
    elif epoch <= 75:
        return 0.0001
    elif epoch <= 100:
        return 0.00005
    else: return 0.00001

# %%
tf.keras.backend.set_image_data_format('channels_first')
tf.keras.backend.image_data_format()
# Out:
# 'channels_first'

# %%
dic_rmse = {}
for i in range(0,10):
    print("loading data...")
    fname = os.path.join(path_cache, 'BikeNYC_C{}_P{}_T{}.h5'.format(
        len_closeness, len_period, len_trend))
    if os.path.exists(fname) and CACHEDATA:
        X_train_all, Y_train_all, X_train, Y_train, \
        X_val, Y_val, X_test, Y_test, mmn, external_dim, \
        timestamp_train_all, timestamp_train, timestamp_val, timestamp_test = read_cache(
            fname)
        print("load %s successfully" % fname)
    else:
        X_train_all, Y_train_all, X_train, Y_train, \
        X_val, Y_val, X_test, Y_test, mmn, external_dim, \
        timestamp_train_all, timestamp_train, timestamp_val, timestamp_test = BikeNYC.load_data(
            T=T, nb_flow=nb_flow, len_closeness=len_closeness, len_period=len_period, len_trend=len_trend, len_test=len_test,
            len_val=len_val, preprocess_name='preprocessing_nyc.pkl', meta_data=True, datapath=DATAPATH)
        if CACHEDATA:
            cache(fname, X_train_all, Y_train_all, X_train, Y_train, X_val, Y_val, X_test, Y_test,
                  external_dim, timestamp_train_all, timestamp_train, timestamp_val, timestamp_test)

    print("\n days (test): ", [v[:8] for v in timestamp_test[0::T]])

    print('=' * 10)
    print("compiling model...")

    lr_callback = LearningRateScheduler(lrschedule)

    model = build_model(external_dim, save_model_pic=False)

    hyperparams_name = 'BikeNYC.c{}.p{}.t{}.resunit{}.iter{}'.format(
        len_closeness, len_period, len_trend, nb_residual_unit, i)
    fname_param = os.path.join(path_model, '{}.best.h5'.format(hyperparams_name))
    print(hyperparams_name)

    early_stopping = EarlyStopping(monitor='val_rmse', patience=24, mode='min')
    model_checkpoint = ModelCheckpoint(
        fname_param, monitor='val_rmse', verbose=1, save_best_only=True, mode='min')

    print('=' * 10)
    print("training model...")
    history = model.fit(X_train, Y_train,
                        epochs=nb_epoch,
                        batch_size=batch_size,
                        validation_data=(X_val,Y_val),
                        callbacks=[early_stopping, model_checkpoint],
                        verbose=0)
    model.save_weights(os.path.join(
        path_model, '{}.h5'.format(hyperparams_name)), overwrite=True)
    pickle.dump((history.history), open(os.path.join(
        path_result, '{}.history.pkl'.format(hyperparams_name)), 'wb'))

    print('=' * 10)
    print('evaluating using the model that has the best loss on the valid set')

    model.load_weights(fname_param)
    
    score = model.evaluate(
        X_test, Y_test, batch_size=Y_test.shape[0], verbose=0)
    print('Test score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
          (score[0], score[1], score[1] * (mmn._max - mmn._min) / 2. ))
# Out:
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# BikeNYC.c3.p1.t1.resunit2.iter0
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.12549, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00002: val_rmse improved from 0.12549 to 0.05760, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00003: val_rmse improved from 0.05760 to 0.05479, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00004: val_rmse improved from 0.05479 to 0.05278, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00005: val_rmse improved from 0.05278 to 0.04952, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00006: val_rmse improved from 0.04952 to 0.04553, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00007: val_rmse improved from 0.04553 to 0.04448, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00008: val_rmse improved from 0.04448 to 0.04433, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00009: val_rmse did not improve from 0.04433
#
# Epoch 00010: val_rmse improved from 0.04433 to 0.04328, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00011: val_rmse improved from 0.04328 to 0.04120, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00012: val_rmse did not improve from 0.04120
#
# Epoch 00013: val_rmse did not improve from 0.04120
#
# Epoch 00014: val_rmse improved from 0.04120 to 0.04047, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00015: val_rmse did not improve from 0.04047
#
# Epoch 00016: val_rmse did not improve from 0.04047
#
# Epoch 00017: val_rmse improved from 0.04047 to 0.03931, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00018: val_rmse did not improve from 0.03931
#
# Epoch 00019: val_rmse did not improve from 0.03931
#
# Epoch 00020: val_rmse did not improve from 0.03931
#
# Epoch 00021: val_rmse did not improve from 0.03931
#
# Epoch 00022: val_rmse did not improve from 0.03931
#
# Epoch 00023: val_rmse did not improve from 0.03931
#
# Epoch 00024: val_rmse improved from 0.03931 to 0.03813, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00025: val_rmse did not improve from 0.03813
#
# Epoch 00026: val_rmse improved from 0.03813 to 0.03747, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00027: val_rmse did not improve from 0.03747
#
# Epoch 00028: val_rmse did not improve from 0.03747
#
# Epoch 00029: val_rmse did not improve from 0.03747
#
# Epoch 00030: val_rmse did not improve from 0.03747
#
# Epoch 00031: val_rmse did not improve from 0.03747
#
# Epoch 00032: val_rmse did not improve from 0.03747
#
# Epoch 00033: val_rmse did not improve from 0.03747
#
# Epoch 00034: val_rmse did not improve from 0.03747
#
# Epoch 00035: val_rmse improved from 0.03747 to 0.03719, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00036: val_rmse did not improve from 0.03719
#
# Epoch 00037: val_rmse did not improve from 0.03719
#
# Epoch 00038: val_rmse did not improve from 0.03719
#
# Epoch 00039: val_rmse did not improve from 0.03719
#
# Epoch 00040: val_rmse improved from 0.03719 to 0.03702, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00041: val_rmse did not improve from 0.03702
#
# Epoch 00042: val_rmse improved from 0.03702 to 0.03651, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00043: val_rmse did not improve from 0.03651
#
# Epoch 00044: val_rmse improved from 0.03651 to 0.03637, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00045: val_rmse did not improve from 0.03637
#
# Epoch 00046: val_rmse did not improve from 0.03637
#
# Epoch 00047: val_rmse did not improve from 0.03637
#
# Epoch 00048: val_rmse did not improve from 0.03637
#
# Epoch 00049: val_rmse did not improve from 0.03637
#
# Epoch 00050: val_rmse improved from 0.03637 to 0.03596, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter0.best.h5
#
# Epoch 00051: val_rmse did not improve from 0.03596
#
# Epoch 00052: val_rmse did not improve from 0.03596
#
# Epoch 00053: val_rmse did not improve from 0.03596
#
# Epoch 00054: val_rmse did not improve from 0.03596
#
# Epoch 00055: val_rmse did not improve from 0.03596
#
# Epoch 00056: val_rmse did not improve from 0.03596
#
# Epoch 00057: val_rmse did not improve from 0.03596
#
# Epoch 00058: val_rmse did not improve from 0.03596
#
# Epoch 00059: val_rmse did not improve from 0.03596
#
# Epoch 00060: val_rmse did not improve from 0.03596
#
# Epoch 00061: val_rmse did not improve from 0.03596
#
# Epoch 00062: val_rmse did not improve from 0.03596
#
# Epoch 00063: val_rmse did not improve from 0.03596
#
# Epoch 00064: val_rmse did not improve from 0.03596
#
# Epoch 00065: val_rmse did not improve from 0.03596
#
# Epoch 00066: val_rmse did not improve from 0.03596
#
# Epoch 00067: val_rmse did not improve from 0.03596
#
# Epoch 00068: val_rmse did not improve from 0.03596
#
# Epoch 00069: val_rmse did not improve from 0.03596
#
# Epoch 00070: val_rmse did not improve from 0.03596
#
# Epoch 00071: val_rmse did not improve from 0.03596
#
# Epoch 00072: val_rmse did not improve from 0.03596
#
# Epoch 00073: val_rmse did not improve from 0.03596
#
# Epoch 00074: val_rmse did not improve from 0.03596
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001297 rmse (norm): 0.036009 rmse (real): 4.807233
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter1
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.13040, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00002: val_rmse improved from 0.13040 to 0.06511, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00003: val_rmse improved from 0.06511 to 0.05398, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00004: val_rmse improved from 0.05398 to 0.05089, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00005: val_rmse improved from 0.05089 to 0.04779, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00006: val_rmse did not improve from 0.04779
#
# Epoch 00007: val_rmse improved from 0.04779 to 0.04600, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00008: val_rmse improved from 0.04600 to 0.04458, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00009: val_rmse improved from 0.04458 to 0.04417, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00010: val_rmse improved from 0.04417 to 0.04341, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00011: val_rmse did not improve from 0.04341
#
# Epoch 00012: val_rmse improved from 0.04341 to 0.04112, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00013: val_rmse did not improve from 0.04112
#
# Epoch 00014: val_rmse did not improve from 0.04112
#
# Epoch 00015: val_rmse did not improve from 0.04112
#
# Epoch 00016: val_rmse did not improve from 0.04112
#
# Epoch 00017: val_rmse improved from 0.04112 to 0.04044, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00018: val_rmse did not improve from 0.04044
#
# Epoch 00019: val_rmse did not improve from 0.04044
#
# Epoch 00020: val_rmse did not improve from 0.04044
#
# Epoch 00021: val_rmse improved from 0.04044 to 0.03926, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00022: val_rmse did not improve from 0.03926
#
# Epoch 00023: val_rmse did not improve from 0.03926
#
# Epoch 00024: val_rmse did not improve from 0.03926
#
# Epoch 00025: val_rmse improved from 0.03926 to 0.03774, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00026: val_rmse did not improve from 0.03774
#
# Epoch 00027: val_rmse did not improve from 0.03774
#
# Epoch 00028: val_rmse did not improve from 0.03774
#
# Epoch 00029: val_rmse did not improve from 0.03774
#
# Epoch 00030: val_rmse did not improve from 0.03774
#
# Epoch 00031: val_rmse did not improve from 0.03774
#
# Epoch 00032: val_rmse improved from 0.03774 to 0.03773, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00033: val_rmse did not improve from 0.03773
#
# Epoch 00034: val_rmse did not improve from 0.03773
#
# Epoch 00035: val_rmse improved from 0.03773 to 0.03767, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00036: val_rmse did not improve from 0.03767
#
# Epoch 00037: val_rmse improved from 0.03767 to 0.03743, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00038: val_rmse improved from 0.03743 to 0.03686, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00039: val_rmse improved from 0.03686 to 0.03660, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00040: val_rmse did not improve from 0.03660
#
# Epoch 00041: val_rmse did not improve from 0.03660
#
# Epoch 00042: val_rmse did not improve from 0.03660
#
# Epoch 00043: val_rmse did not improve from 0.03660
#
# Epoch 00044: val_rmse did not improve from 0.03660
#
# Epoch 00045: val_rmse improved from 0.03660 to 0.03658, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00046: val_rmse did not improve from 0.03658
#
# Epoch 00047: val_rmse did not improve from 0.03658
#
# Epoch 00048: val_rmse did not improve from 0.03658
#
# Epoch 00049: val_rmse did not improve from 0.03658
#
# Epoch 00050: val_rmse did not improve from 0.03658
#
# Epoch 00051: val_rmse did not improve from 0.03658
#
# Epoch 00052: val_rmse did not improve from 0.03658
#
# Epoch 00053: val_rmse did not improve from 0.03658
#
# Epoch 00054: val_rmse did not improve from 0.03658
#
# Epoch 00055: val_rmse did not improve from 0.03658
#
# Epoch 00056: val_rmse did not improve from 0.03658
#
# Epoch 00057: val_rmse improved from 0.03658 to 0.03618, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00058: val_rmse did not improve from 0.03618
#
# Epoch 00059: val_rmse improved from 0.03618 to 0.03616, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00060: val_rmse improved from 0.03616 to 0.03603, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00061: val_rmse did not improve from 0.03603
#
# Epoch 00062: val_rmse did not improve from 0.03603
#
# Epoch 00063: val_rmse did not improve from 0.03603
#
# Epoch 00064: val_rmse did not improve from 0.03603
#
# Epoch 00065: val_rmse did not improve from 0.03603
#
# Epoch 00066: val_rmse improved from 0.03603 to 0.03574, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter1.best.h5
#
# Epoch 00067: val_rmse did not improve from 0.03574
#
# Epoch 00068: val_rmse did not improve from 0.03574
#
# Epoch 00069: val_rmse did not improve from 0.03574
#
# Epoch 00070: val_rmse did not improve from 0.03574
#
# Epoch 00071: val_rmse did not improve from 0.03574
#
# Epoch 00072: val_rmse did not improve from 0.03574
#
# Epoch 00073: val_rmse did not improve from 0.03574
#
# Epoch 00074: val_rmse did not improve from 0.03574
#
# Epoch 00075: val_rmse did not improve from 0.03574
#
# Epoch 00076: val_rmse did not improve from 0.03574
#
# Epoch 00077: val_rmse did not improve from 0.03574
#
# Epoch 00078: val_rmse did not improve from 0.03574
#
# Epoch 00079: val_rmse did not improve from 0.03574
#
# Epoch 00080: val_rmse did not improve from 0.03574
#
# Epoch 00081: val_rmse did not improve from 0.03574
#
# Epoch 00082: val_rmse did not improve from 0.03574
#
# Epoch 00083: val_rmse did not improve from 0.03574
#
# Epoch 00084: val_rmse did not improve from 0.03574
#
# Epoch 00085: val_rmse did not improve from 0.03574
#
# Epoch 00086: val_rmse did not improve from 0.03574
#
# Epoch 00087: val_rmse did not improve from 0.03574
#
# Epoch 00088: val_rmse did not improve from 0.03574
#
# Epoch 00089: val_rmse did not improve from 0.03574
#
# Epoch 00090: val_rmse did not improve from 0.03574
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001291 rmse (norm): 0.035935 rmse (real): 4.797284
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter2
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.07833, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00002: val_rmse improved from 0.07833 to 0.06093, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00003: val_rmse improved from 0.06093 to 0.04962, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00004: val_rmse improved from 0.04962 to 0.04789, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00005: val_rmse did not improve from 0.04789
#
# Epoch 00006: val_rmse did not improve from 0.04789
#
# Epoch 00007: val_rmse improved from 0.04789 to 0.04415, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00008: val_rmse did not improve from 0.04415
#
# Epoch 00009: val_rmse did not improve from 0.04415
#
# Epoch 00010: val_rmse improved from 0.04415 to 0.04172, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00011: val_rmse did not improve from 0.04172
#
# Epoch 00012: val_rmse improved from 0.04172 to 0.04162, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00013: val_rmse improved from 0.04162 to 0.04076, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00014: val_rmse improved from 0.04076 to 0.03991, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00015: val_rmse did not improve from 0.03991
#
# Epoch 00016: val_rmse did not improve from 0.03991
#
# Epoch 00017: val_rmse did not improve from 0.03991
#
# Epoch 00018: val_rmse improved from 0.03991 to 0.03922, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00019: val_rmse did not improve from 0.03922
#
# Epoch 00020: val_rmse did not improve from 0.03922
#
# Epoch 00021: val_rmse improved from 0.03922 to 0.03912, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00022: val_rmse did not improve from 0.03912
#
# Epoch 00023: val_rmse did not improve from 0.03912
#
# Epoch 00024: val_rmse did not improve from 0.03912
#
# Epoch 00025: val_rmse improved from 0.03912 to 0.03783, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00026: val_rmse did not improve from 0.03783
#
# Epoch 00027: val_rmse did not improve from 0.03783
#
# Epoch 00028: val_rmse did not improve from 0.03783
#
# Epoch 00029: val_rmse did not improve from 0.03783
#
# Epoch 00030: val_rmse did not improve from 0.03783
#
# Epoch 00031: val_rmse did not improve from 0.03783
#
# Epoch 00032: val_rmse improved from 0.03783 to 0.03753, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00033: val_rmse did not improve from 0.03753
#
# Epoch 00034: val_rmse did not improve from 0.03753
#
# Epoch 00035: val_rmse improved from 0.03753 to 0.03751, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00036: val_rmse did not improve from 0.03751
#
# Epoch 00037: val_rmse did not improve from 0.03751
#
# Epoch 00038: val_rmse did not improve from 0.03751
#
# Epoch 00039: val_rmse improved from 0.03751 to 0.03668, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00040: val_rmse did not improve from 0.03668
#
# Epoch 00041: val_rmse did not improve from 0.03668
#
# Epoch 00042: val_rmse did not improve from 0.03668
#
# Epoch 00043: val_rmse did not improve from 0.03668
#
# Epoch 00044: val_rmse improved from 0.03668 to 0.03634, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00045: val_rmse did not improve from 0.03634
#
# Epoch 00046: val_rmse did not improve from 0.03634
#
# Epoch 00047: val_rmse improved from 0.03634 to 0.03623, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00048: val_rmse did not improve from 0.03623
#
# Epoch 00049: val_rmse did not improve from 0.03623
#
# Epoch 00050: val_rmse did not improve from 0.03623
#
# Epoch 00051: val_rmse did not improve from 0.03623
#
# Epoch 00052: val_rmse did not improve from 0.03623
#
# Epoch 00053: val_rmse did not improve from 0.03623
#
# Epoch 00054: val_rmse did not improve from 0.03623
#
# Epoch 00055: val_rmse did not improve from 0.03623
#
# Epoch 00056: val_rmse did not improve from 0.03623
#
# Epoch 00057: val_rmse did not improve from 0.03623
#
# Epoch 00058: val_rmse did not improve from 0.03623
#
# Epoch 00059: val_rmse did not improve from 0.03623
#
# Epoch 00060: val_rmse did not improve from 0.03623
#
# Epoch 00061: val_rmse did not improve from 0.03623
#
# Epoch 00062: val_rmse improved from 0.03623 to 0.03610, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00063: val_rmse did not improve from 0.03610
#
# Epoch 00064: val_rmse improved from 0.03610 to 0.03593, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00065: val_rmse did not improve from 0.03593
#
# Epoch 00066: val_rmse improved from 0.03593 to 0.03589, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00067: val_rmse did not improve from 0.03589
#
# Epoch 00068: val_rmse did not improve from 0.03589
#
# Epoch 00069: val_rmse did not improve from 0.03589
#
# Epoch 00070: val_rmse did not improve from 0.03589
#
# Epoch 00071: val_rmse improved from 0.03589 to 0.03577, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00072: val_rmse did not improve from 0.03577
#
# Epoch 00073: val_rmse did not improve from 0.03577
#
# Epoch 00074: val_rmse did not improve from 0.03577
#
# Epoch 00075: val_rmse improved from 0.03577 to 0.03572, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter2.best.h5
#
# Epoch 00076: val_rmse did not improve from 0.03572
#
# Epoch 00077: val_rmse did not improve from 0.03572
#
# Epoch 00078: val_rmse did not improve from 0.03572
#
# Epoch 00079: val_rmse did not improve from 0.03572
#
# Epoch 00080: val_rmse did not improve from 0.03572
#
# Epoch 00081: val_rmse did not improve from 0.03572
#
# Epoch 00082: val_rmse did not improve from 0.03572
#
# Epoch 00083: val_rmse did not improve from 0.03572
#
# Epoch 00084: val_rmse did not improve from 0.03572
#
# Epoch 00085: val_rmse did not improve from 0.03572
#
# Epoch 00086: val_rmse did not improve from 0.03572
#
# Epoch 00087: val_rmse did not improve from 0.03572
#
# Epoch 00088: val_rmse did not improve from 0.03572
#
# Epoch 00089: val_rmse did not improve from 0.03572
#
# Epoch 00090: val_rmse did not improve from 0.03572
#
# Epoch 00091: val_rmse did not improve from 0.03572
#
# Epoch 00092: val_rmse did not improve from 0.03572
#
# Epoch 00093: val_rmse did not improve from 0.03572
#
# Epoch 00094: val_rmse did not improve from 0.03572
#
# Epoch 00095: val_rmse did not improve from 0.03572
#
# Epoch 00096: val_rmse did not improve from 0.03572
#
# Epoch 00097: val_rmse did not improve from 0.03572
#
# Epoch 00098: val_rmse did not improve from 0.03572
#
# Epoch 00099: val_rmse did not improve from 0.03572
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001305 rmse (norm): 0.036129 rmse (real): 4.823221
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter3
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.07285, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00002: val_rmse improved from 0.07285 to 0.05645, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00003: val_rmse improved from 0.05645 to 0.05160, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00004: val_rmse improved from 0.05160 to 0.04794, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00005: val_rmse did not improve from 0.04794
#
# Epoch 00006: val_rmse improved from 0.04794 to 0.04574, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00007: val_rmse improved from 0.04574 to 0.04357, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00008: val_rmse did not improve from 0.04357
#
# Epoch 00009: val_rmse improved from 0.04357 to 0.04301, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00010: val_rmse improved from 0.04301 to 0.04085, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00011: val_rmse did not improve from 0.04085
#
# Epoch 00012: val_rmse improved from 0.04085 to 0.03996, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00013: val_rmse did not improve from 0.03996
#
# Epoch 00014: val_rmse did not improve from 0.03996
#
# Epoch 00015: val_rmse improved from 0.03996 to 0.03934, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00016: val_rmse improved from 0.03934 to 0.03881, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00017: val_rmse did not improve from 0.03881
#
# Epoch 00018: val_rmse did not improve from 0.03881
#
# Epoch 00019: val_rmse improved from 0.03881 to 0.03816, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00020: val_rmse did not improve from 0.03816
#
# Epoch 00021: val_rmse improved from 0.03816 to 0.03799, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00022: val_rmse did not improve from 0.03799
#
# Epoch 00023: val_rmse did not improve from 0.03799
#
# Epoch 00024: val_rmse did not improve from 0.03799
#
# Epoch 00025: val_rmse did not improve from 0.03799
#
# Epoch 00026: val_rmse did not improve from 0.03799
#
# Epoch 00027: val_rmse improved from 0.03799 to 0.03777, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00028: val_rmse did not improve from 0.03777
#
# Epoch 00029: val_rmse improved from 0.03777 to 0.03736, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00030: val_rmse did not improve from 0.03736
#
# Epoch 00031: val_rmse improved from 0.03736 to 0.03696, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00032: val_rmse did not improve from 0.03696
#
# Epoch 00033: val_rmse did not improve from 0.03696
#
# Epoch 00034: val_rmse improved from 0.03696 to 0.03685, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00035: val_rmse did not improve from 0.03685
#
# Epoch 00036: val_rmse did not improve from 0.03685
#
# Epoch 00037: val_rmse did not improve from 0.03685
#
# Epoch 00038: val_rmse improved from 0.03685 to 0.03644, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00039: val_rmse did not improve from 0.03644
#
# Epoch 00040: val_rmse did not improve from 0.03644
#
# Epoch 00041: val_rmse did not improve from 0.03644
#
# Epoch 00042: val_rmse did not improve from 0.03644
#
# Epoch 00043: val_rmse improved from 0.03644 to 0.03635, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00044: val_rmse did not improve from 0.03635
#
# Epoch 00045: val_rmse did not improve from 0.03635
#
# Epoch 00046: val_rmse improved from 0.03635 to 0.03620, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00047: val_rmse did not improve from 0.03620
#
# Epoch 00048: val_rmse did not improve from 0.03620
#
# Epoch 00049: val_rmse did not improve from 0.03620
#
# Epoch 00050: val_rmse did not improve from 0.03620
#
# Epoch 00051: val_rmse did not improve from 0.03620
#
# Epoch 00052: val_rmse did not improve from 0.03620
#
# Epoch 00053: val_rmse did not improve from 0.03620
#
# Epoch 00054: val_rmse did not improve from 0.03620
#
# Epoch 00055: val_rmse did not improve from 0.03620
#
# Epoch 00056: val_rmse did not improve from 0.03620
#
# Epoch 00057: val_rmse did not improve from 0.03620
#
# Epoch 00058: val_rmse improved from 0.03620 to 0.03601, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00059: val_rmse did not improve from 0.03601
#
# Epoch 00060: val_rmse did not improve from 0.03601
#
# Epoch 00061: val_rmse did not improve from 0.03601
#
# Epoch 00062: val_rmse did not improve from 0.03601
#
# Epoch 00063: val_rmse did not improve from 0.03601
#
# Epoch 00064: val_rmse did not improve from 0.03601
#
# Epoch 00065: val_rmse did not improve from 0.03601
#
# Epoch 00066: val_rmse improved from 0.03601 to 0.03583, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00067: val_rmse did not improve from 0.03583
#
# Epoch 00068: val_rmse did not improve from 0.03583
#
# Epoch 00069: val_rmse did not improve from 0.03583
#
# Epoch 00070: val_rmse did not improve from 0.03583
#
# Epoch 00071: val_rmse did not improve from 0.03583
#
# Epoch 00072: val_rmse did not improve from 0.03583
#
# Epoch 00073: val_rmse did not improve from 0.03583
#
# Epoch 00074: val_rmse did not improve from 0.03583
#
# Epoch 00075: val_rmse did not improve from 0.03583
#
# Epoch 00076: val_rmse did not improve from 0.03583
#
# Epoch 00077: val_rmse did not improve from 0.03583
#
# Epoch 00078: val_rmse improved from 0.03583 to 0.03568, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00079: val_rmse did not improve from 0.03568
#
# Epoch 00080: val_rmse did not improve from 0.03568
#
# Epoch 00081: val_rmse did not improve from 0.03568
#
# Epoch 00082: val_rmse did not improve from 0.03568
#
# Epoch 00083: val_rmse did not improve from 0.03568
#
# Epoch 00084: val_rmse did not improve from 0.03568
#
# Epoch 00085: val_rmse did not improve from 0.03568
#
# Epoch 00086: val_rmse did not improve from 0.03568
#
# Epoch 00087: val_rmse improved from 0.03568 to 0.03546, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter3.best.h5
#
# Epoch 00088: val_rmse did not improve from 0.03546
#
# Epoch 00089: val_rmse did not improve from 0.03546
#
# Epoch 00090: val_rmse did not improve from 0.03546
#
# Epoch 00091: val_rmse did not improve from 0.03546
#
# Epoch 00092: val_rmse did not improve from 0.03546
#
# Epoch 00093: val_rmse did not improve from 0.03546
#
# Epoch 00094: val_rmse did not improve from 0.03546
#
# Epoch 00095: val_rmse did not improve from 0.03546
#
# Epoch 00096: val_rmse did not improve from 0.03546
#
# Epoch 00097: val_rmse did not improve from 0.03546
#
# Epoch 00098: val_rmse did not improve from 0.03546
#
# Epoch 00099: val_rmse did not improve from 0.03546
#
# Epoch 00100: val_rmse did not improve from 0.03546
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001264 rmse (norm): 0.035557 rmse (real): 4.746861
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter4
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.08956, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00002: val_rmse improved from 0.08956 to 0.06114, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00003: val_rmse improved from 0.06114 to 0.05383, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00004: val_rmse did not improve from 0.05383
#
# Epoch 00005: val_rmse improved from 0.05383 to 0.04879, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00006: val_rmse did not improve from 0.04879
#
# Epoch 00007: val_rmse improved from 0.04879 to 0.04482, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00008: val_rmse did not improve from 0.04482
#
# Epoch 00009: val_rmse improved from 0.04482 to 0.04353, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00010: val_rmse did not improve from 0.04353
#
# Epoch 00011: val_rmse improved from 0.04353 to 0.04297, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00012: val_rmse did not improve from 0.04297
#
# Epoch 00013: val_rmse improved from 0.04297 to 0.04187, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00014: val_rmse did not improve from 0.04187
#
# Epoch 00015: val_rmse did not improve from 0.04187
#
# Epoch 00016: val_rmse did not improve from 0.04187
#
# Epoch 00017: val_rmse improved from 0.04187 to 0.04072, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00018: val_rmse improved from 0.04072 to 0.03956, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00019: val_rmse did not improve from 0.03956
#
# Epoch 00020: val_rmse improved from 0.03956 to 0.03920, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00021: val_rmse improved from 0.03920 to 0.03869, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00022: val_rmse did not improve from 0.03869
#
# Epoch 00023: val_rmse did not improve from 0.03869
#
# Epoch 00024: val_rmse did not improve from 0.03869
#
# Epoch 00025: val_rmse improved from 0.03869 to 0.03802, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00026: val_rmse did not improve from 0.03802
#
# Epoch 00027: val_rmse did not improve from 0.03802
#
# Epoch 00028: val_rmse did not improve from 0.03802
#
# Epoch 00029: val_rmse did not improve from 0.03802
#
# Epoch 00030: val_rmse improved from 0.03802 to 0.03795, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00031: val_rmse improved from 0.03795 to 0.03757, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00032: val_rmse improved from 0.03757 to 0.03737, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00033: val_rmse improved from 0.03737 to 0.03720, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00034: val_rmse did not improve from 0.03720
#
# Epoch 00035: val_rmse did not improve from 0.03720
#
# Epoch 00036: val_rmse did not improve from 0.03720
#
# Epoch 00037: val_rmse did not improve from 0.03720
#
# Epoch 00038: val_rmse improved from 0.03720 to 0.03673, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00039: val_rmse did not improve from 0.03673
#
# Epoch 00040: val_rmse did not improve from 0.03673
#
# Epoch 00041: val_rmse did not improve from 0.03673
#
# Epoch 00042: val_rmse did not improve from 0.03673
#
# Epoch 00043: val_rmse did not improve from 0.03673
#
# Epoch 00044: val_rmse did not improve from 0.03673
#
# Epoch 00045: val_rmse did not improve from 0.03673
#
# Epoch 00046: val_rmse did not improve from 0.03673
#
# Epoch 00047: val_rmse did not improve from 0.03673
#
# Epoch 00048: val_rmse improved from 0.03673 to 0.03666, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00049: val_rmse did not improve from 0.03666
#
# Epoch 00050: val_rmse did not improve from 0.03666
#
# Epoch 00051: val_rmse improved from 0.03666 to 0.03636, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00052: val_rmse improved from 0.03636 to 0.03618, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00053: val_rmse did not improve from 0.03618
#
# Epoch 00054: val_rmse did not improve from 0.03618
#
# Epoch 00055: val_rmse improved from 0.03618 to 0.03612, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00056: val_rmse did not improve from 0.03612
#
# Epoch 00057: val_rmse did not improve from 0.03612
#
# Epoch 00058: val_rmse did not improve from 0.03612
#
# Epoch 00059: val_rmse did not improve from 0.03612
#
# Epoch 00060: val_rmse did not improve from 0.03612
#
# Epoch 00061: val_rmse did not improve from 0.03612
#
# Epoch 00062: val_rmse did not improve from 0.03612
#
# Epoch 00063: val_rmse improved from 0.03612 to 0.03586, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00064: val_rmse improved from 0.03586 to 0.03559, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00065: val_rmse improved from 0.03559 to 0.03550, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter4.best.h5
#
# Epoch 00066: val_rmse did not improve from 0.03550
#
# Epoch 00067: val_rmse did not improve from 0.03550
#
# Epoch 00068: val_rmse did not improve from 0.03550
#
# Epoch 00069: val_rmse did not improve from 0.03550
#
# Epoch 00070: val_rmse did not improve from 0.03550
#
# Epoch 00071: val_rmse did not improve from 0.03550
#
# Epoch 00072: val_rmse did not improve from 0.03550
#
# Epoch 00073: val_rmse did not improve from 0.03550
#
# Epoch 00074: val_rmse did not improve from 0.03550
#
# Epoch 00075: val_rmse did not improve from 0.03550
#
# Epoch 00076: val_rmse did not improve from 0.03550
#
# Epoch 00077: val_rmse did not improve from 0.03550
#
# Epoch 00078: val_rmse did not improve from 0.03550
#
# Epoch 00079: val_rmse did not improve from 0.03550
#
# Epoch 00080: val_rmse did not improve from 0.03550
#
# Epoch 00081: val_rmse did not improve from 0.03550
#
# Epoch 00082: val_rmse did not improve from 0.03550
#
# Epoch 00083: val_rmse did not improve from 0.03550
#
# Epoch 00084: val_rmse did not improve from 0.03550
#
# Epoch 00085: val_rmse did not improve from 0.03550
#
# Epoch 00086: val_rmse did not improve from 0.03550
#
# Epoch 00087: val_rmse did not improve from 0.03550
#
# Epoch 00088: val_rmse did not improve from 0.03550
#
# Epoch 00089: val_rmse did not improve from 0.03550
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001314 rmse (norm): 0.036247 rmse (real): 4.838976
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter5
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.08696, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00002: val_rmse improved from 0.08696 to 0.07033, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00003: val_rmse improved from 0.07033 to 0.05564, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00004: val_rmse improved from 0.05564 to 0.05091, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00005: val_rmse improved from 0.05091 to 0.04647, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00006: val_rmse improved from 0.04647 to 0.04487, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00007: val_rmse did not improve from 0.04487
#
# Epoch 00008: val_rmse improved from 0.04487 to 0.04332, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00009: val_rmse improved from 0.04332 to 0.04223, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00010: val_rmse did not improve from 0.04223
#
# Epoch 00011: val_rmse improved from 0.04223 to 0.04111, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00012: val_rmse did not improve from 0.04111
#
# Epoch 00013: val_rmse improved from 0.04111 to 0.04069, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00014: val_rmse improved from 0.04069 to 0.04030, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00015: val_rmse did not improve from 0.04030
#
# Epoch 00016: val_rmse did not improve from 0.04030
#
# Epoch 00017: val_rmse did not improve from 0.04030
#
# Epoch 00018: val_rmse improved from 0.04030 to 0.03915, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00019: val_rmse did not improve from 0.03915
#
# Epoch 00020: val_rmse did not improve from 0.03915
#
# Epoch 00021: val_rmse did not improve from 0.03915
#
# Epoch 00022: val_rmse did not improve from 0.03915
#
# Epoch 00023: val_rmse improved from 0.03915 to 0.03830, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00024: val_rmse did not improve from 0.03830
#
# Epoch 00025: val_rmse improved from 0.03830 to 0.03784, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00026: val_rmse did not improve from 0.03784
#
# Epoch 00027: val_rmse did not improve from 0.03784
#
# Epoch 00028: val_rmse did not improve from 0.03784
#
# Epoch 00029: val_rmse improved from 0.03784 to 0.03748, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00030: val_rmse did not improve from 0.03748
#
# Epoch 00031: val_rmse did not improve from 0.03748
#
# Epoch 00032: val_rmse did not improve from 0.03748
#
# Epoch 00033: val_rmse did not improve from 0.03748
#
# Epoch 00034: val_rmse did not improve from 0.03748
#
# Epoch 00035: val_rmse improved from 0.03748 to 0.03714, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00036: val_rmse did not improve from 0.03714
#
# Epoch 00037: val_rmse improved from 0.03714 to 0.03688, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00038: val_rmse improved from 0.03688 to 0.03687, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00039: val_rmse did not improve from 0.03687
#
# Epoch 00040: val_rmse did not improve from 0.03687
#
# Epoch 00041: val_rmse did not improve from 0.03687
#
# Epoch 00042: val_rmse improved from 0.03687 to 0.03665, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00043: val_rmse improved from 0.03665 to 0.03663, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00044: val_rmse improved from 0.03663 to 0.03649, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00045: val_rmse did not improve from 0.03649
#
# Epoch 00046: val_rmse did not improve from 0.03649
#
# Epoch 00047: val_rmse improved from 0.03649 to 0.03630, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00048: val_rmse did not improve from 0.03630
#
# Epoch 00049: val_rmse did not improve from 0.03630
#
# Epoch 00050: val_rmse did not improve from 0.03630
#
# Epoch 00051: val_rmse did not improve from 0.03630
#
# Epoch 00052: val_rmse improved from 0.03630 to 0.03619, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00053: val_rmse improved from 0.03619 to 0.03598, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00054: val_rmse did not improve from 0.03598
#
# Epoch 00055: val_rmse did not improve from 0.03598
#
# Epoch 00056: val_rmse did not improve from 0.03598
#
# Epoch 00057: val_rmse did not improve from 0.03598
#
# Epoch 00058: val_rmse did not improve from 0.03598
#
# Epoch 00059: val_rmse did not improve from 0.03598
#
# Epoch 00060: val_rmse did not improve from 0.03598
#
# Epoch 00061: val_rmse did not improve from 0.03598
#
# Epoch 00062: val_rmse improved from 0.03598 to 0.03593, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00063: val_rmse did not improve from 0.03593
#
# Epoch 00064: val_rmse did not improve from 0.03593
#
# Epoch 00065: val_rmse improved from 0.03593 to 0.03584, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00066: val_rmse did not improve from 0.03584
#
# Epoch 00067: val_rmse did not improve from 0.03584
#
# Epoch 00068: val_rmse improved from 0.03584 to 0.03573, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00069: val_rmse did not improve from 0.03573
#
# Epoch 00070: val_rmse did not improve from 0.03573
#
# Epoch 00071: val_rmse did not improve from 0.03573
#
# Epoch 00072: val_rmse did not improve from 0.03573
#
# Epoch 00073: val_rmse did not improve from 0.03573
#
# Epoch 00074: val_rmse did not improve from 0.03573
#
# Epoch 00075: val_rmse did not improve from 0.03573
#
# Epoch 00076: val_rmse did not improve from 0.03573
#
# Epoch 00077: val_rmse did not improve from 0.03573
#
# Epoch 00078: val_rmse did not improve from 0.03573
#
# Epoch 00079: val_rmse did not improve from 0.03573
#
# Epoch 00080: val_rmse did not improve from 0.03573
#
# Epoch 00081: val_rmse did not improve from 0.03573
#
# Epoch 00082: val_rmse did not improve from 0.03573
#
# Epoch 00083: val_rmse did not improve from 0.03573
#
# Epoch 00084: val_rmse did not improve from 0.03573
#
# Epoch 00085: val_rmse did not improve from 0.03573
#
# Epoch 00086: val_rmse did not improve from 0.03573
#
# Epoch 00087: val_rmse did not improve from 0.03573
#
# Epoch 00088: val_rmse did not improve from 0.03573
#
# Epoch 00089: val_rmse did not improve from 0.03573
#
# Epoch 00090: val_rmse did not improve from 0.03573
#
# Epoch 00091: val_rmse did not improve from 0.03573
#
# Epoch 00092: val_rmse improved from 0.03573 to 0.03572, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter5.best.h5
#
# Epoch 00093: val_rmse did not improve from 0.03572
#
# Epoch 00094: val_rmse did not improve from 0.03572
#
# Epoch 00095: val_rmse did not improve from 0.03572
#
# Epoch 00096: val_rmse did not improve from 0.03572
#
# Epoch 00097: val_rmse did not improve from 0.03572
#
# Epoch 00098: val_rmse did not improve from 0.03572
#
# Epoch 00099: val_rmse did not improve from 0.03572
#
# Epoch 00100: val_rmse did not improve from 0.03572
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001299 rmse (norm): 0.036048 rmse (real): 4.812411
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter6
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.08409, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00002: val_rmse improved from 0.08409 to 0.05856, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00003: val_rmse improved from 0.05856 to 0.05252, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00004: val_rmse improved from 0.05252 to 0.05071, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00005: val_rmse did not improve from 0.05071
#
# Epoch 00006: val_rmse improved from 0.05071 to 0.04534, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00007: val_rmse did not improve from 0.04534
#
# Epoch 00008: val_rmse improved from 0.04534 to 0.04358, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00009: val_rmse did not improve from 0.04358
#
# Epoch 00010: val_rmse did not improve from 0.04358
#
# Epoch 00011: val_rmse improved from 0.04358 to 0.04242, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00012: val_rmse improved from 0.04242 to 0.04135, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00013: val_rmse did not improve from 0.04135
#
# Epoch 00014: val_rmse improved from 0.04135 to 0.04012, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00015: val_rmse did not improve from 0.04012
#
# Epoch 00016: val_rmse did not improve from 0.04012
#
# Epoch 00017: val_rmse improved from 0.04012 to 0.03978, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00018: val_rmse improved from 0.03978 to 0.03946, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00019: val_rmse improved from 0.03946 to 0.03873, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00020: val_rmse did not improve from 0.03873
#
# Epoch 00021: val_rmse did not improve from 0.03873
#
# Epoch 00022: val_rmse did not improve from 0.03873
#
# Epoch 00023: val_rmse did not improve from 0.03873
#
# Epoch 00024: val_rmse did not improve from 0.03873
#
# Epoch 00025: val_rmse did not improve from 0.03873
#
# Epoch 00026: val_rmse improved from 0.03873 to 0.03863, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00027: val_rmse did not improve from 0.03863
#
# Epoch 00028: val_rmse did not improve from 0.03863
#
# Epoch 00029: val_rmse improved from 0.03863 to 0.03788, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00030: val_rmse did not improve from 0.03788
#
# Epoch 00031: val_rmse improved from 0.03788 to 0.03787, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00032: val_rmse improved from 0.03787 to 0.03743, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00033: val_rmse did not improve from 0.03743
#
# Epoch 00034: val_rmse did not improve from 0.03743
#
# Epoch 00035: val_rmse did not improve from 0.03743
#
# Epoch 00036: val_rmse improved from 0.03743 to 0.03713, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00037: val_rmse did not improve from 0.03713
#
# Epoch 00038: val_rmse improved from 0.03713 to 0.03695, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00039: val_rmse did not improve from 0.03695
#
# Epoch 00040: val_rmse did not improve from 0.03695
#
# Epoch 00041: val_rmse improved from 0.03695 to 0.03688, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00042: val_rmse improved from 0.03688 to 0.03661, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# Epoch 00043: val_rmse did not improve from 0.03661
#
# Epoch 00044: val_rmse did not improve from 0.03661
#
# Epoch 00045: val_rmse did not improve from 0.03661
#
# Epoch 00046: val_rmse did not improve from 0.03661
#
# Epoch 00047: val_rmse did not improve from 0.03661
#
# Epoch 00048: val_rmse did not improve from 0.03661
#
# Epoch 00049: val_rmse did not improve from 0.03661
#
# Epoch 00050: val_rmse did not improve from 0.03661
#
# Epoch 00051: val_rmse did not improve from 0.03661
#
# Epoch 00052: val_rmse did not improve from 0.03661
#
# Epoch 00053: val_rmse did not improve from 0.03661
#
# Epoch 00054: val_rmse did not improve from 0.03661
#
# Epoch 00055: val_rmse did not improve from 0.03661
#
# Epoch 00056: val_rmse did not improve from 0.03661
#
# Epoch 00057: val_rmse did not improve from 0.03661
#
# Epoch 00058: val_rmse did not improve from 0.03661
#
# Epoch 00059: val_rmse improved from 0.03661 to 0.03648, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter6.best.h5
#
# ...
#
# Epoch 00062: val_rmse did not improve from 0.03617
#
# Epoch 00063: val_rmse did not improve from 0.03617
#
# Epoch 00064: val_rmse did not improve from 0.03617
#
# Epoch 00065: val_rmse improved from 0.03617 to 0.03616, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter7.best.h5
#
# Epoch 00066: val_rmse did not improve from 0.03616
#
# Epoch 00067: val_rmse improved from 0.03616 to 0.03585, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter7.best.h5
#
# Epoch 00068: val_rmse did not improve from 0.03585
#
# Epoch 00069: val_rmse did not improve from 0.03585
#
# Epoch 00070: val_rmse did not improve from 0.03585
#
# Epoch 00071: val_rmse did not improve from 0.03585
#
# Epoch 00072: val_rmse did not improve from 0.03585
#
# Epoch 00073: val_rmse did not improve from 0.03585
#
# Epoch 00074: val_rmse did not improve from 0.03585
#
# Epoch 00075: val_rmse did not improve from 0.03585
#
# Epoch 00076: val_rmse did not improve from 0.03585
#
# Epoch 00077: val_rmse did not improve from 0.03585
#
# Epoch 00078: val_rmse did not improve from 0.03585
#
# Epoch 00079: val_rmse did not improve from 0.03585
#
# Epoch 00080: val_rmse did not improve from 0.03585
#
# Epoch 00081: val_rmse did not improve from 0.03585
#
# Epoch 00082: val_rmse did not improve from 0.03585
#
# Epoch 00083: val_rmse did not improve from 0.03585
#
# Epoch 00084: val_rmse did not improve from 0.03585
#
# Epoch 00085: val_rmse did not improve from 0.03585
#
# Epoch 00086: val_rmse did not improve from 0.03585
#
# Epoch 00087: val_rmse did not improve from 0.03585
#
# Epoch 00088: val_rmse did not improve from 0.03585
#
# Epoch 00089: val_rmse did not improve from 0.03585
#
# Epoch 00090: val_rmse did not improve from 0.03585
#
# Epoch 00091: val_rmse did not improve from 0.03585
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001284 rmse (norm): 0.035837 rmse (real): 4.784272
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter8
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.07865, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00002: val_rmse improved from 0.07865 to 0.05835, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00003: val_rmse improved from 0.05835 to 0.05536, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00004: val_rmse improved from 0.05536 to 0.04989, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00005: val_rmse did not improve from 0.04989
#
# Epoch 00006: val_rmse improved from 0.04989 to 0.04731, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00007: val_rmse improved from 0.04731 to 0.04521, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00008: val_rmse did not improve from 0.04521
#
# Epoch 00009: val_rmse did not improve from 0.04521
#
# Epoch 00010: val_rmse improved from 0.04521 to 0.04221, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00011: val_rmse did not improve from 0.04221
#
# Epoch 00012: val_rmse did not improve from 0.04221
#
# Epoch 00013: val_rmse did not improve from 0.04221
#
# Epoch 00014: val_rmse improved from 0.04221 to 0.04099, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00015: val_rmse did not improve from 0.04099
#
# Epoch 00016: val_rmse did not improve from 0.04099
#
# Epoch 00017: val_rmse improved from 0.04099 to 0.04023, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00018: val_rmse improved from 0.04023 to 0.03989, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00019: val_rmse did not improve from 0.03989
#
# Epoch 00020: val_rmse improved from 0.03989 to 0.03930, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00021: val_rmse did not improve from 0.03930
#
# Epoch 00022: val_rmse improved from 0.03930 to 0.03894, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00023: val_rmse did not improve from 0.03894
#
# Epoch 00024: val_rmse did not improve from 0.03894
#
# Epoch 00025: val_rmse did not improve from 0.03894
#
# Epoch 00026: val_rmse did not improve from 0.03894
#
# Epoch 00027: val_rmse improved from 0.03894 to 0.03794, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00028: val_rmse did not improve from 0.03794
#
# Epoch 00029: val_rmse did not improve from 0.03794
#
# Epoch 00030: val_rmse did not improve from 0.03794
#
# Epoch 00031: val_rmse improved from 0.03794 to 0.03735, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00032: val_rmse did not improve from 0.03735
#
# Epoch 00033: val_rmse did not improve from 0.03735
#
# Epoch 00034: val_rmse did not improve from 0.03735
#
# Epoch 00035: val_rmse did not improve from 0.03735
#
# Epoch 00036: val_rmse did not improve from 0.03735
#
# Epoch 00037: val_rmse did not improve from 0.03735
#
# Epoch 00038: val_rmse did not improve from 0.03735
#
# Epoch 00039: val_rmse did not improve from 0.03735
#
# Epoch 00040: val_rmse did not improve from 0.03735
#
# Epoch 00041: val_rmse did not improve from 0.03735
#
# Epoch 00042: val_rmse did not improve from 0.03735
#
# Epoch 00043: val_rmse improved from 0.03735 to 0.03709, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00044: val_rmse did not improve from 0.03709
#
# Epoch 00045: val_rmse improved from 0.03709 to 0.03700, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00046: val_rmse did not improve from 0.03700
#
# Epoch 00047: val_rmse improved from 0.03700 to 0.03643, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00048: val_rmse did not improve from 0.03643
#
# Epoch 00049: val_rmse did not improve from 0.03643
#
# Epoch 00050: val_rmse did not improve from 0.03643
#
# Epoch 00051: val_rmse did not improve from 0.03643
#
# Epoch 00052: val_rmse did not improve from 0.03643
#
# Epoch 00053: val_rmse did not improve from 0.03643
#
# Epoch 00054: val_rmse did not improve from 0.03643
#
# Epoch 00055: val_rmse did not improve from 0.03643
#
# Epoch 00056: val_rmse did not improve from 0.03643
#
# Epoch 00057: val_rmse did not improve from 0.03643
#
# Epoch 00058: val_rmse improved from 0.03643 to 0.03603, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00059: val_rmse did not improve from 0.03603
#
# Epoch 00060: val_rmse did not improve from 0.03603
#
# Epoch 00061: val_rmse did not improve from 0.03603
#
# Epoch 00062: val_rmse did not improve from 0.03603
#
# Epoch 00063: val_rmse did not improve from 0.03603
#
# Epoch 00064: val_rmse did not improve from 0.03603
#
# Epoch 00065: val_rmse did not improve from 0.03603
#
# Epoch 00066: val_rmse did not improve from 0.03603
#
# Epoch 00067: val_rmse did not improve from 0.03603
#
# Epoch 00068: val_rmse did not improve from 0.03603
#
# Epoch 00069: val_rmse did not improve from 0.03603
#
# Epoch 00070: val_rmse did not improve from 0.03603
#
# Epoch 00071: val_rmse did not improve from 0.03603
#
# Epoch 00072: val_rmse did not improve from 0.03603
#
# Epoch 00073: val_rmse did not improve from 0.03603
#
# Epoch 00074: val_rmse did not improve from 0.03603
#
# Epoch 00075: val_rmse did not improve from 0.03603
#
# Epoch 00076: val_rmse did not improve from 0.03603
#
# Epoch 00077: val_rmse did not improve from 0.03603
#
# Epoch 00078: val_rmse did not improve from 0.03603
#
# Epoch 00079: val_rmse did not improve from 0.03603
#
# Epoch 00080: val_rmse improved from 0.03603 to 0.03598, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00081: val_rmse did not improve from 0.03598
#
# Epoch 00082: val_rmse improved from 0.03598 to 0.03593, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00083: val_rmse did not improve from 0.03593
#
# Epoch 00084: val_rmse improved from 0.03593 to 0.03590, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00085: val_rmse did not improve from 0.03590
#
# Epoch 00086: val_rmse did not improve from 0.03590
#
# Epoch 00087: val_rmse did not improve from 0.03590
#
# Epoch 00088: val_rmse did not improve from 0.03590
#
# Epoch 00089: val_rmse did not improve from 0.03590
#
# Epoch 00090: val_rmse did not improve from 0.03590
#
# Epoch 00091: val_rmse did not improve from 0.03590
#
# Epoch 00092: val_rmse did not improve from 0.03590
#
# Epoch 00093: val_rmse did not improve from 0.03590
#
# Epoch 00094: val_rmse did not improve from 0.03590
#
# Epoch 00095: val_rmse did not improve from 0.03590
#
# Epoch 00096: val_rmse did not improve from 0.03590
#
# Epoch 00097: val_rmse improved from 0.03590 to 0.03583, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00098: val_rmse improved from 0.03583 to 0.03583, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter8.best.h5
#
# Epoch 00099: val_rmse did not improve from 0.03583
#
# Epoch 00100: val_rmse did not improve from 0.03583
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001302 rmse (norm): 0.036082 rmse (real): 4.816899
# loading data...
# load ../data/CACHE/STAR/BikeNYC_C3_P1_T1.h5 successfully
#
#  days (test):  [b'20140921', b'20140922', b'20140923', b'20140924', b'20140925', b'20140926', b'20140927', b'20140928', b'20140929', b'20140930']
# ==========
# compiling model...
# BikeNYC.c3.p1.t1.resunit2.iter9
# ==========
# training model...
#
# Epoch 00001: val_rmse improved from inf to 0.12506, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00002: val_rmse improved from 0.12506 to 0.05927, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00003: val_rmse improved from 0.05927 to 0.05172, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00004: val_rmse improved from 0.05172 to 0.04813, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00005: val_rmse improved from 0.04813 to 0.04660, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00006: val_rmse did not improve from 0.04660
#
# Epoch 00007: val_rmse improved from 0.04660 to 0.04558, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00008: val_rmse did not improve from 0.04558
#
# Epoch 00009: val_rmse improved from 0.04558 to 0.04294, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00010: val_rmse did not improve from 0.04294
#
# Epoch 00011: val_rmse improved from 0.04294 to 0.04157, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00012: val_rmse did not improve from 0.04157
#
# Epoch 00013: val_rmse improved from 0.04157 to 0.04024, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00014: val_rmse did not improve from 0.04024
#
# Epoch 00015: val_rmse improved from 0.04024 to 0.04000, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00016: val_rmse improved from 0.04000 to 0.03910, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00017: val_rmse did not improve from 0.03910
#
# Epoch 00018: val_rmse improved from 0.03910 to 0.03899, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00019: val_rmse did not improve from 0.03899
#
# Epoch 00020: val_rmse did not improve from 0.03899
#
# Epoch 00021: val_rmse did not improve from 0.03899
#
# Epoch 00022: val_rmse improved from 0.03899 to 0.03876, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00023: val_rmse improved from 0.03876 to 0.03811, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00024: val_rmse did not improve from 0.03811
#
# Epoch 00025: val_rmse did not improve from 0.03811
#
# Epoch 00026: val_rmse did not improve from 0.03811
#
# Epoch 00027: val_rmse did not improve from 0.03811
#
# Epoch 00028: val_rmse improved from 0.03811 to 0.03764, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00029: val_rmse did not improve from 0.03764
#
# Epoch 00030: val_rmse did not improve from 0.03764
#
# Epoch 00031: val_rmse did not improve from 0.03764
#
# Epoch 00032: val_rmse improved from 0.03764 to 0.03710, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00033: val_rmse did not improve from 0.03710
#
# Epoch 00034: val_rmse did not improve from 0.03710
#
# Epoch 00035: val_rmse did not improve from 0.03710
#
# Epoch 00036: val_rmse did not improve from 0.03710
#
# Epoch 00037: val_rmse did not improve from 0.03710
#
# Epoch 00038: val_rmse did not improve from 0.03710
#
# Epoch 00039: val_rmse did not improve from 0.03710
#
# Epoch 00040: val_rmse improved from 0.03710 to 0.03704, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00041: val_rmse did not improve from 0.03704
#
# Epoch 00042: val_rmse did not improve from 0.03704
#
# Epoch 00043: val_rmse improved from 0.03704 to 0.03686, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00044: val_rmse improved from 0.03686 to 0.03615, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00045: val_rmse did not improve from 0.03615
#
# Epoch 00046: val_rmse did not improve from 0.03615
#
# Epoch 00047: val_rmse did not improve from 0.03615
#
# Epoch 00048: val_rmse did not improve from 0.03615
#
# Epoch 00049: val_rmse did not improve from 0.03615
#
# Epoch 00050: val_rmse did not improve from 0.03615
#
# Epoch 00051: val_rmse did not improve from 0.03615
#
# Epoch 00052: val_rmse did not improve from 0.03615
#
# Epoch 00053: val_rmse improved from 0.03615 to 0.03594, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00054: val_rmse did not improve from 0.03594
#
# Epoch 00055: val_rmse did not improve from 0.03594
#
# Epoch 00056: val_rmse did not improve from 0.03594
#
# Epoch 00057: val_rmse did not improve from 0.03594
#
# Epoch 00058: val_rmse did not improve from 0.03594
#
# Epoch 00059: val_rmse did not improve from 0.03594
#
# Epoch 00060: val_rmse did not improve from 0.03594
#
# Epoch 00061: val_rmse did not improve from 0.03594
#
# Epoch 00062: val_rmse improved from 0.03594 to 0.03591, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00063: val_rmse did not improve from 0.03591
#
# Epoch 00064: val_rmse did not improve from 0.03591
#
# Epoch 00065: val_rmse did not improve from 0.03591
#
# Epoch 00066: val_rmse did not improve from 0.03591
#
# Epoch 00067: val_rmse did not improve from 0.03591
#
# Epoch 00068: val_rmse did not improve from 0.03591
#
# Epoch 00069: val_rmse did not improve from 0.03591
#
# Epoch 00070: val_rmse did not improve from 0.03591
#
# Epoch 00071: val_rmse did not improve from 0.03591
#
# Epoch 00072: val_rmse did not improve from 0.03591
#
# Epoch 00073: val_rmse improved from 0.03591 to 0.03565, saving model to MODEL/BikeNYC.c3.p1.t1.resunit2.iter9.best.h5
#
# Epoch 00074: val_rmse did not improve from 0.03565
#
# Epoch 00075: val_rmse did not improve from 0.03565
#
# Epoch 00076: val_rmse did not improve from 0.03565
#
# Epoch 00077: val_rmse did not improve from 0.03565
#
# Epoch 00078: val_rmse did not improve from 0.03565
#
# Epoch 00079: val_rmse did not improve from 0.03565
#
# Epoch 00080: val_rmse did not improve from 0.03565
#
# Epoch 00081: val_rmse did not improve from 0.03565
#
# Epoch 00082: val_rmse did not improve from 0.03565
#
# Epoch 00083: val_rmse did not improve from 0.03565
#
# Epoch 00084: val_rmse did not improve from 0.03565
#
# Epoch 00085: val_rmse did not improve from 0.03565
#
# Epoch 00086: val_rmse did not improve from 0.03565
#
# Epoch 00087: val_rmse did not improve from 0.03565
#
# Epoch 00088: val_rmse did not improve from 0.03565
#
# Epoch 00089: val_rmse did not improve from 0.03565
#
# Epoch 00090: val_rmse did not improve from 0.03565
#
# Epoch 00091: val_rmse did not improve from 0.03565
#
# Epoch 00092: val_rmse did not improve from 0.03565
#
# Epoch 00093: val_rmse did not improve from 0.03565
#
# Epoch 00094: val_rmse did not improve from 0.03565
#
# Epoch 00095: val_rmse did not improve from 0.03565
#
# Epoch 00096: val_rmse did not improve from 0.03565
#
# Epoch 00097: val_rmse did not improve from 0.03565
# ==========
# evaluating using the model that has the best loss on the valid set
# Test score: 0.001301 rmse (norm): 0.036066 rmse (real): 4.814817

# %%
# Out:
# 5.9624999999999995
